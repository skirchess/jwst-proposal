# %%
from POSEIDON.core import create_star, create_planet
from POSEIDON.constants import R_J, R_Sun

R_s = 0.42*R_Sun
T_s = 3600
log_g_s = 4.85
Met_s = -0.5

star = create_star(R_s, T_s, log_g_s, Met_s)

planet_name = 'TOI-1266 c'
R_p = 0.139*R_J
T_eq = 345.87
g_p = 8.87769

planet = create_planet(planet_name, R_p, gravity=g_p, T_eq=T_eq)

# %%
from POSEIDON.core import define_model, read_opacities, make_atmosphere, compute_spectrum
import numpy as np

model_name = '95%CO2 5% H2O'

bulk_species = ['CO2']
param_species = ['H2O']

# Create the model object
model = define_model(model_name, bulk_species, param_species,
                     PT_profile = 'isotherm', cloud_model = 'cloud-free')

# Specify the pressure grid of the atmosphere
P_min = 1.0e-7    # 0.1 ubar
P_max = 100       # 100 bar
N_layers = 100    # 100 layers

P = np.logspace(np.log10(P_max), np.log10(P_min), N_layers)

# Specify the reference pressure and radius
P_ref = 1         # 1 bar
R_p_ref = R_p         # Radius at reference pressure

# Provide a specific set of model parameters for the atmosphere
PT_params = np.array([T_eq])              # Assume terminator temperature is T_eq
log_X_params = np.array([-1.3010])   # CO2 H2 log abundances in model
                    #H2O% 5
# Generate the atmosphere
atmosphere = make_atmosphere(planet, model, P, P_ref, R_p_ref, PT_params, log_X_params)

# %%
from POSEIDON.core import wl_grid_constant_R

wl_min = 0.5
wl_max = 5.5
R = 10000

wl = wl_grid_constant_R(wl_min, wl_max, R)

#***Reading Opacities***#

opacity_treatment = 'opacity_sampling'

# Define fine temperature grid (K)
T_fine_min = 100     # Same as prior range for T
T_fine_max = 1000    # Same as prior range for T
T_fine_step = 10     # 10 K steps are a good tradeoff between accuracy and RAM

T_fine = np.arange(T_fine_min, (T_fine_max + T_fine_step), T_fine_step)

# Define fine pressure grid (log10(P/bar))
log_P_fine_min = -6   # 1 ubar is the lowest pressure in the opacity database
log_P_fine_max = 2    # 100 bar is the highest pressure in the opacity database
log_P_fine_step = 0.2   # 0.2 dex steps are a good tradeoff between accuracy and RAM

log_P_fine = np.arange(log_P_fine_min, (log_P_fine_max + log_P_fine_step),
                       log_P_fine_step)

# Pre-interpolate the opacities (note: model wavelength range was initialised in cell above)
opac = read_opacities(model, wl, opacity_treatment, T_fine, log_P_fine)
# Out:
# Reading in cross sections in opacity sampling mode...
# CO2-CO2 done
# CO2 done
# H2O done
# Opacity pre-interpolation complete.

# %%
from POSEIDON.visuals import plot_spectra
from POSEIDON.utility import plot_collection

spectrum = compute_spectrum(planet, star, model, atmosphere, opac, wl,
                            spectrum_type = 'transmission')
spectra = []

spectra = plot_collection(spectrum, wl, collection = spectra)

fig_spec = plot_spectra(spectra, planet, R_to_bin = 100, 
                        plot_full_res=True, figure_shape='wide', spectra_labels=['CO2 with 5% H2O-Model'], plt_label='Forward Model for Proposal', wl_axis='linear')

# %%
#####TEST CELL FOR H2O feature

# Define new mixing ratio array with a low CO2 abundance
log_X_params_no_CH4 = np.array([-100])  # log(H2O)

# Create a new atmosphere without CO2
atmosphere_no_CH4 = make_atmosphere(planet, model, P, P_ref, R_p_ref,
                                    PT_params, log_X_params_no_CH4)

# Generate the new transmission spectrum
spectrum_no_CH4 = compute_spectrum(planet, star, model, atmosphere_no_CH4,
                                   opac, wl, spectrum_type = 'transmission')

# Add the spectrum we want to plot to our existing plot collection
spectra = plot_collection(spectrum_no_CH4, wl, collection = spectra)

# Produce figure
fig_spec = plot_spectra(spectra, planet, R_to_bin = 100,
                        spectra_labels = ['CO2 with 5% H2O', 'No H$_2$O'], figure_shape='wide', plot_full_res=True, wl_axis='linear')
# high mean molecular weight CO2 makes low transit depth.

# %%
# Do not run below cell if you ran cell for identifying molecular feature

# %%
# for j in range(1):
#     for i in range(len(spectra[0][1])):
#         print(spectra[0][j+1][i],' ', spectra[0][j][i])

instrument = 'NIRSpec Prism'

outfile = open(planet_name + '_JWST_' + instrument + "_" + bulk_species[0] + param_species[0] + "_spectra_file.txt","w")
for j in range(1): # wl in column 1 and T.D in column 2
    for i in range(len(spectra[0][1])):
        outfile.writelines(str(spectra[0][j+1][i]))
        outfile.writelines('\t')
        outfile.writelines(str(spectra[0][j][i]))
        outfile.writelines('\n')
outfile.close()

# %%
# change kernel to pandexo

# %%
# assign a core to numpy
import os
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'
os.environ['CBLAS_NUM_THREADS'] = '1'

# %%
# import necessary modules
import warnings
warnings.filterwarnings('ignore')
import pandexo.engine.justdoit as jdi
import pandexo.engine.justplotit as jpi
import astropy
import pickle as pk
import numpy as np
import scipy.constants as sc

# %%
# This is used to write the data with specific order
def write_data(planet_dir, wl_data, bin_size, spectrum, err_data, 
               instrument, N_trans, NRS_detector, NIRISS_order, model):
    
    if (instrument == 'NIRISS SOSS'): # for NIRISS SOSS order #
        suffix = '_Ord' + str(NIRISS_order)
    elif (('NIRSpec G' in instrument) and ('H' in instrument)): #for NIRSpec G H detector
        suffix = '_NRS' + str(NRS_detector)
    else: #for all other instruments, no suffix
        suffix = ''
    
    f = open(planet_dir + '/' + planet_name + '_' + model + '_' +
             instrument + suffix + '_N_trans_' + str(N_trans) + '.dat', 'w')
    
    for i in range(len(wl_data)): # f for float, e for scientific notation
        f.write('%.8f %.8f %.8e %.8e \n' %(wl_data[i], bin_size[i], spectrum[i], err_data[i]))
    
    f.close()

# %%
#planet and instrument properties

planet_name = 'TOI-1266 c'
model = 'CO2+5%H2O'

N_trans = 1 # no. of transits

instrument = 'NIRSpec Prism' #other instruments such as NIRISS SOSS, MIRI LRS
NIRISS_order = 1     # 1st or 2nd order for NIRISS SOSS only

# ***Create output directories***

# Specify desired paths of output directories to be created

output_dir = './data'
planet_dir = output_dir + '/' + planet_name

# create main output directory named 'data' which will include planet directory
if (os.path.exists(output_dir) == False):
    os.mkdir(output_dir)
    
if (os.path.exists(planet_dir) == False):
    os.mkdir(planet_dir)
    
# check the directory once

# %%
# PandExo settings

Trans_duration = 2.05 # Transit duration of TOI-1266 c, in hours, from ExoMast

#Loads in empty exoplanet dictionary for pandexo input, to edit planetary params
exo_dict = jdi.load_exo_dict() 

exo_dict['observation']['sat_level'] = 80                # Saturation level in percent of full well
exo_dict['observation']['sat_unit'] = '%'                 # Other option = 'e' for electrons
exo_dict['observation']['noccultations'] = N_trans        # Number of transits
exo_dict['observation']['R'] = None                       # Fixed binning. I usually suggest ZERO binning.. you can always bin later
exo_dict['observation']['baseline'] = 3.8*60.0*60.0        # Time spent observing out of transit, make sure to specify units
exo_dict['observation']['baseline_unit'] = 'total'         # Total observing time, other option 'frac' = in/out
exo_dict['observation']['noise_floor'] = 10                # This can be a fixed level or it can be a filepath

# The stellar properties below are for L 98- 59 b from ExoMast and SIMBAD (except for stellar metallicity)
exo_dict['star']['type'] = 'phoenix'        # Phoenix or user (if you have your own)
exo_dict['star']['mag'] = 9.706                # Magnitude of the system
exo_dict['star']['ref_wave'] = 1.25         # For J mag = 1.25, H = 1.6, K =2.22.. etc (all in micron)
exo_dict['star']['temp'] = 3600             # (K)
exo_dict['star']['metal'] = 0.0             # ALWAYS USE 0.0 FOR PHOENIX MODELS (there's a bug at non-solar metallicities)
exo_dict['star']['logg'] = 4.85             # Log surface gravity (cgs)
exo_dict['star']['radius'] = 0.42
exo_dict['star']['r_unit'] = 'R_sun'

exo_dict['planet']['type'] = 'user'#tells pandexo you want a user defined transit depth, can be user defined check JWST_Running_Pandexo_w_ExoMAST.ipynb
exo_dict['planet']['exopath'] = 'TOI-1266 c_JWST_NIRSpec Prism_CO2H2O_spectra_file.txt'
exo_dict['planet']['w_unit'] = 'um'            # Other options include "um","nm" ,"Angs", "secs" (for phase curves)
exo_dict['planet']['radius'] = 0.139               # We're just using a flat spectrum here, will scatter errors about a model later
exo_dict['planet']['r_unit'] = 'R_jup'
exo_dict['planet']['f_unit'] = 'rp^2/r*^2'     #this is what you would do for primary transit 

exo_dict['planet']['transit_duration'] = Trans_duration*60*60.0     # Transit duration in seconds
exo_dict['planet']['td_unit'] = 's'

# %%
#***** Begin PandExo run *****#
print('Running PandExo for ' + instrument)

inst_dict = jdi.load_mode_dict(instrument)

# if (instrument == 'NIRSpec Prism'):
#     inst_dict["configuration"]["detector"]["subarray"] = 'sub2048'
# #     inst_dict["strategy"]["order"] = NIRISS_order

print(inst_dict["configuration"]["detector"]["subarray"])
print(inst_dict["configuration"]["instrument"]["filter"])
# Out:
# Running PandExo for NIRSpec Prism
# sub512
# clear

# %%
result = jdi.run_pandexo(exo_dict, inst_dict, output_path = planet_dir, output_file = planet_name + '_'+ instrument+ '_95CO25H2O' + '.p')

print(result['timing'])
print()
print(result['warning'])
# Out:
# Running Single Case w/ User Instrument Dict
# Optimization Reqested: Computing Duty Cycle
# Finished Duty Cycle Calc
# Starting Out of Transit Simulation
# End out of Transit
# Starting In Transit Simulation
# End In Transit
# {'Transit Duration': 2.05, 'Seconds per Frame': 0.22616, 'Time/Integration incl reset (sec)': 0.67848, 'APT: Num Groups per Integration': 2, 'Num Integrations Out of Transit': 9287, 'Num Integrations In Transit': 10878, 'APT: Num Integrations per Occultation': 20165, 'Observing Efficiency (%)': 33.33333333333333, 'Transit+Baseline, no overhead (hrs)': 3.800430333333333, 'Number of Transits': 1}
#
# {'Group Number Too Low?': 'All good', 'Group Number Too High?': 'All good', 'Non linear?': 'All good', 'Saturated?': 'Full saturation:\n There are 112 pixels saturated at the end of the first group. These pixels cannot be recovered.', '% full well high?': 'All good', 'Num Groups Reset?': 'NGROUPS<2SET TO NGROUPS=2'}

# %%
out = pk.load((open(planet_dir + '/' + planet_name + '_'+ instrument + '_95CO25H2O' '.p', 'rb')))

wl_data, ydata, err_data = jpi.jwst_1d_spec(out, num_tran=N_trans, plot=True, model=True)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1219">Loading BokehJS ...</span>
#     </div>
#   <div id="ff21fdbc-1ce6-45a6-aeb3-e97c2ff3ecf5" data-root-id="p1220" style="display: contents;"></div>

# %%
half_width = 0.5 * np.diff(wl_data[0], append=np.array([wl_data[0][-1] + (wl_data[0][-1] - wl_data[0][-2])]))
keep_err = 1e-3 # Error criteria to keep data point (< 1000 ppm), trims things like data in band gaps
wl_data_out = wl_data[0][np.where(err_data[0]<= keep_err)]
half_width_out = half_width[np.where(err_data[0]<=keep_err)]
ydata_out = ydata[0][np.where(err_data[0]<=keep_err)]
err_data_out = err_data[0][np.where(err_data[0]<=keep_err)]

# %%
#For NIRSpec
if (('NIRSpec G' in instrument) and ('H' in instrument)):
    NRS_1_idx = np.argwhere(wl_data_out < band_gaps[instrument])
    NRS_2_idx = np.argwhere(wl_data_out > band_gaps[instrument])
    
    wl_NRS_1 = wl_data_out[NRS_1_idx]
    half_width_NRS_1 = half_width_out[NRS_1_idx]
    ydata_NRS_1 = ydata_out[NRS_1_idx]
    err_data_NRS_1 = err_data_out[NRS_1_idx]

    wl_NRS_2 = wl_data_out[NRS_2_idx]
    half_width_NRS_2 = half_width_out[NRS_2_idx]
    ydata_NRS_2 = ydata_out[NRS_2_idx]
    err_data_NRS_2 = err_data_out[NRS_2_idx]
    
    NRS_detector = 1
    write_data(planet_dir, wl_NRS_1, half_width_NRS_1, ydata_NRS_1, err_data_NRS_1, instrument, N_trans, NRS_detector, NIRISS_order, model)

    NRS_detector = 2
    write_data(planet_dir, wl_NRS_2, half_width_NRS_2, ydata_NRS_2, err_data_NRS_2, instrument, N_trans, NRS_detector, NIRISS_order, model)
    
else:
    NRS_detector = 0
    
    write_data(planet_dir, wl_data_out, half_width_out, ydata_out, err_data_out, instrument, N_trans, NRS_detector, NIRISS_order, model)

# %%
print('Mean ' +str(1e6*np.mean(err_data_out)) + ' ppm')
# Out:
# Mean 125.21693904828825 ppm

# %%
# Change kernel to POSEIDON

# %%
from POSEIDON.core import load_data, wl_grid_constant_R
from POSEIDON.visuals import plot_data
# Out:
# /home/swaroop/anaconda3/envs/poseidon/lib/python3.9/site-packages/pysynphot/locations.py:345: UserWarning: Extinction files not found in /home/swaroop/sample/grp/redcat/trds/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))
# /home/swaroop/POSEIDON/POSEIDON/absorption.py:1466: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def store_Rayleigh_eta_LBL(wl_model, chemical_species):

# %%
planet_name = 'TOI-1266 c'

wl_min = 0.5
wl_max = 5.5

R = 10000

wl = wl_grid_constant_R(wl_min, wl_max, R)

data_dir = './data/' + planet_name

datasets = [planet_name + '_CO2+5%H2O_NIRSpec Prism_N_trans_1.dat']
#This datasets is obtained from pandexo snippet

instruments = ['JWST_NIRSpec_Prism']

data = load_data(data_dir, datasets, instruments, wl)

fig_data = plot_data(data, planet_name, wl_min, wl_max, wl_axis='linear',
                     data_labels = ['NIRSpec_Prism'], 
                     plt_label = 'PandExo Output')

# %%
#run first four cells to call the params again

# %%
from POSEIDON.instrument import generate_syn_data_from_file
N_trans = [1]

R_to_bin = [100]

generate_syn_data_from_file(planet, wl, spectrum, data_dir, data, R_to_bin = R_to_bin, N_trans=N_trans, label=model_name, Gauss_scatter=True)
# Out:
# Creating synthetic data
# JWST_NIRSpec_Prism

# %%
# Now synthetic data (pandexo simulated data is scattered around poseidon model using plot from poseidon) 
datasets_new = [planet_name + '_SYNTHETIC_JWST_NIRSpec_Prism_' + model_name + '_N_trans_' + str(N_trans[0]) + '.dat',]

#datasets_new = ['L 98-59 b_SYNTHETIC_JWST_MIRI_LRS_Venus-like_N_trans_1.dat']
data_new = load_data(data_dir, datasets_new, instruments, wl)

spectra = []

spectra = plot_collection(spectrum, wl, collection = spectra)

fig_spec = plot_spectra(spectra, planet, data_properties=data_new, R_to_bin=100, plot_full_res=False, show_data = True, figure_shape='wide', wl_min=0.6, wl_max=5.3, wl_axis='linear')

# %%
from POSEIDON.core import set_priors

prior_types = {}
prior_ranges = {}

prior_types['T'] = 'uniform'
prior_types['R_p_ref'] = 'uniform'
prior_types['log_X'] = 'uniform'

prior_ranges['T'] = [100, 1000]
prior_ranges['R_p_ref'] = [0.85*R_p, 1.15*R_p]
prior_ranges['log_X'] = [-12,-1] 

priors = set_priors(planet, star, model, data, prior_types, prior_ranges)

# %%
from POSEIDON.retrieval import run_retrieval

run_retrieval(planet, star, model, opac, data_new, priors, wl, P, P_ref, 
             R=R, spectrum_type='transmission', sampling_algorithm=
              'MultiNest', N_live = 400, verbose=True, resume = False)
# Out:
# POSEIDON now running '95%CO2 5% H2O'
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  400
#  dimensionality =    3
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.989011
# Replacements:                                450
# Total Samples:                               455
# Nested Sampling ln(Z):             -24323.741111
# Acceptance Rate:                        0.956023
# Replacements:                                500
# Total Samples:                               523
# Nested Sampling ln(Z):             -17943.668431
# Acceptance Rate:                        0.940171
# Replacements:                                550
# Total Samples:                               585
# Nested Sampling ln(Z):             -13631.026460
# Acceptance Rate:                        0.917431
# Replacements:                                600
# Total Samples:                               654
# Nested Sampling ln(Z):             -10380.816339
# Acceptance Rate:                        0.877193
# Replacements:                                650
# Total Samples:                               741
# Nested Sampling ln(Z):              -7355.225004
# Acceptance Rate:                        0.834327
# Replacements:                                700
# Total Samples:                               839
# Nested Sampling ln(Z):              -4997.955094
# Acceptance Rate:                        0.822368
# Replacements:                                750
# Total Samples:                               912
# Nested Sampling ln(Z):              -3523.242302
# Acceptance Rate:                        0.808898
# Replacements:                                800
# Total Samples:                               989
# Nested Sampling ln(Z):              -2375.396776
# Acceptance Rate:                        0.786309
# Replacements:                                850
# Total Samples:                              1081
# Nested Sampling ln(Z):              -1653.281286
# Acceptance Rate:                        0.783290
# Replacements:                                900
# Total Samples:                              1149
# Nested Sampling ln(Z):               -781.433028
# Acceptance Rate:                        0.769231
# Replacements:                                950
# Total Samples:                              1235
# Nested Sampling ln(Z):               -210.048358
# Acceptance Rate:                        0.755858
# Replacements:                               1000
# Total Samples:                              1323
# Nested Sampling ln(Z):                239.696901
# Acceptance Rate:                        0.741002
# Replacements:                               1050
# Total Samples:                              1417
# Nested Sampling ln(Z):                557.013660
# Acceptance Rate:                        0.739744
# Replacements:                               1100
# Total Samples:                              1487
# Nested Sampling ln(Z):                807.834533
# Acceptance Rate:                        0.731087
# Replacements:                               1150
# Total Samples:                              1573
# Nested Sampling ln(Z):               1075.556891
# Acceptance Rate:                        0.722022
# Replacements:                               1200
# Total Samples:                              1662
# Nested Sampling ln(Z):               1237.914179
# Acceptance Rate:                        0.722543
# Replacements:                               1250
# Total Samples:                              1730
# Nested Sampling ln(Z):               1391.121169
# Acceptance Rate:                        0.718629
# Replacements:                               1300
# Total Samples:                              1809
# Nested Sampling ln(Z):               1518.183149
# Acceptance Rate:                        0.709034
# Replacements:                               1350
# Total Samples:                              1904
# Nested Sampling ln(Z):               1610.776258
# Acceptance Rate:                        0.701052
# Replacements:                               1400
# Total Samples:                              1997
# Nested Sampling ln(Z):               1704.050039
# Acceptance Rate:                        0.686878
# Replacements:                               1450
# Total Samples:                              2111
# Nested Sampling ln(Z):               1771.959249
# Acceptance Rate:                        0.675980
# Replacements:                               1500
# Total Samples:                              2219
# Nested Sampling ln(Z):               1814.951950
# Acceptance Rate:                        0.675970
# Replacements:                               1550
# Total Samples:                              2293
# Nested Sampling ln(Z):               1855.855217
# Acceptance Rate:                        0.676247
# Replacements:                               1600
# Total Samples:                              2366
# Nested Sampling ln(Z):               1882.334188
# Acceptance Rate:                        0.674847
# Replacements:                               1650
# Total Samples:                              2445
# Nested Sampling ln(Z):               1905.070503
# Acceptance Rate:                        0.672202
# Replacements:                               1700
# Total Samples:                              2529
# Nested Sampling ln(Z):               1922.192516
# Acceptance Rate:                        0.668960
# Replacements:                               1750
# Total Samples:                              2616
# Nested Sampling ln(Z):               1937.930172
# Acceptance Rate:                        0.667408
# Replacements:                               1800
# Total Samples:                              2697
# Nested Sampling ln(Z):               1947.613488
# Acceptance Rate:                        0.665468
# Replacements:                               1850
# Total Samples:                              2780
# Nested Sampling ln(Z):               1956.969987
# Acceptance Rate:                        0.665033
# Replacements:                               1900
# Total Samples:                              2857
# Nested Sampling ln(Z):               1964.290499
# Acceptance Rate:                        0.663943
# Replacements:                               1950
# Total Samples:                              2937
# Nested Sampling ln(Z):               1970.183454
# Acceptance Rate:                        0.662691
# Replacements:                               2000
# Total Samples:                              3018
# Nested Sampling ln(Z):               1975.276776
# Acceptance Rate:                        0.657895
# Replacements:                               2050
# Total Samples:                              3116
# Nested Sampling ln(Z):               1979.040552
# Acceptance Rate:                        0.655840
# Replacements:                               2100
# Total Samples:                              3202
# Nested Sampling ln(Z):               1982.972707
# Acceptance Rate:                        0.655288
# Replacements:                               2150
# Total Samples:                              3281
# Nested Sampling ln(Z):               1985.468532
# Acceptance Rate:                        0.655933
# Replacements:                               2200
# Total Samples:                              3354
# Nested Sampling ln(Z):               1987.726029
# Acceptance Rate:                        0.655022
# Replacements:                               2250
# Total Samples:                              3435
# Nested Sampling ln(Z):               1989.509077
# Acceptance Rate:                        0.655831
# Replacements:                               2300
# Total Samples:                              3507
# Nested Sampling ln(Z):               1991.255919
# Acceptance Rate:                        0.653504
# Replacements:                               2350
# Total Samples:                              3596
# Nested Sampling ln(Z):               1992.878229
# Acceptance Rate:                        0.650054
# Replacements:                               2400
# Total Samples:                              3692
# Nested Sampling ln(Z):               1994.254442
# Acceptance Rate:                        0.649351
# Replacements:                               2450
# Total Samples:                              3773
# Nested Sampling ln(Z):               1995.174278
# Acceptance Rate:                        0.651042
# Replacements:                               2500
# Total Samples:                              3840
# Nested Sampling ln(Z):               1996.021818
# Acceptance Rate:                        0.650344
# Replacements:                               2550
# Total Samples:                              3921
# Nested Sampling ln(Z):               1996.825782
# Acceptance Rate:                        0.650000
# Replacements:                               2600
# Total Samples:                              4000
# Nested Sampling ln(Z):               1997.464505
# Acceptance Rate:                        0.650946
# Replacements:                               2650
# Total Samples:                              4071
# Nested Sampling ln(Z):               1997.996702
# Acceptance Rate:                        0.651702
# Replacements:                               2700
# Total Samples:                              4143
# Nested Sampling ln(Z):               1998.426852
# Acceptance Rate:                        0.649197
# Replacements:                               2750
# Total Samples:                              4236
# Nested Sampling ln(Z):               1998.785216
# Acceptance Rate:                        0.649501
# Replacements:                               2800
# Total Samples:                              4311
# Nested Sampling ln(Z):               1999.080696
# Acceptance Rate:                        0.647580
# Replacements:                               2850
# Total Samples:                              4401
# Nested Sampling ln(Z):               1999.323558
# Acceptance Rate:                        0.647900
# Replacements:                               2900
# Total Samples:                              4476
# Nested Sampling ln(Z):               1999.528345
# Acceptance Rate:                        0.647214
# Replacements:                               2950
# Total Samples:                              4558
# Nested Sampling ln(Z):               1999.707523
# Acceptance Rate:                        0.647249
# Replacements:                               3000
# Total Samples:                              4635
# Nested Sampling ln(Z):               1999.860287
# Acceptance Rate:                        0.646735
# Replacements:                               3050
# Total Samples:                              4716
# Nested Sampling ln(Z):               1999.992466
# Acceptance Rate:                        0.647182
# Replacements:                               3100
# Total Samples:                              4790
# Nested Sampling ln(Z):               2000.109377
# Acceptance Rate:                        0.646817
# Replacements:                               3150
# Total Samples:                              4870
# Nested Sampling ln(Z):               2000.212156
# Acceptance Rate:                        0.643734
# Replacements:                               3200
# Total Samples:                              4971
# Nested Sampling ln(Z):               2000.304733
# Acceptance Rate:                        0.642419
# Replacements:                               3250
# Total Samples:                              5059
# Nested Sampling ln(Z):               2000.387382
# Acceptance Rate:                        0.640528
# Replacements:                               3300
# Total Samples:                              5152
# Nested Sampling ln(Z):               2000.464902
# Acceptance Rate:                        0.638704
# Replacements:                               3350
# Total Samples:                              5245
# Nested Sampling ln(Z):               2000.539861
# Acceptance Rate:                        0.636347
# Replacements:                               3400
# Total Samples:                              5343
# Nested Sampling ln(Z):               2000.612567
# Acceptance Rate:                        0.635476
# Replacements:                               3450
# Total Samples:                              5429
# Nested Sampling ln(Z):               2000.680635
# Acceptance Rate:                        0.634403
# Replacements:                               3500
# Total Samples:                              5517
# Nested Sampling ln(Z):               2000.744356
# Acceptance Rate:                        0.632460
# Replacements:                               3550
# Total Samples:                              5613
# Nested Sampling ln(Z):               2000.805507
# Acceptance Rate:                        0.631579
# Replacements:                               3600
# Total Samples:                              5700
# Nested Sampling ln(Z):               2000.861392
# Acceptance Rate:                        0.630615
# Replacements:                               3650
# Total Samples:                              5788
# Nested Sampling ln(Z):               2000.912245
# Acceptance Rate:                        0.627651
# Replacements:                               3700
# Total Samples:                              5895
# Nested Sampling ln(Z):               2000.959580
# Acceptance Rate:                        0.627825
# Replacements:                               3750
# Total Samples:                              5973
# Nested Sampling ln(Z):               2001.004001
# Acceptance Rate:                        0.628099
# Replacements:                               3800
# Total Samples:                              6050
# Nested Sampling ln(Z):               2001.045151
# Acceptance Rate:                        0.628469
# Replacements:                               3850
# Total Samples:                              6126
# Nested Sampling ln(Z):               2001.082868
# Acceptance Rate:                        0.626506
# Replacements:                               3900
# Total Samples:                              6225
# Nested Sampling ln(Z):               2001.117236
# Acceptance Rate:                        0.626428
# Replacements:                               3949
# Total Samples:                              6304
# Nested Sampling ln(Z):               2001.147962
# POSEIDON retrieval finished in 0.38 hours
#  ln(ev)=   2001.4345494049539      +/-  0.12355896304344097
#  Total Likelihood Evaluations:         6304
#  Sampling finished. Exiting MultiNest
# Now generating 1000 sampled spectra and P-T profiles from the posterior distribution...
# This process will take approximately 3.0 minutes
# All done! Output files can be found in ./POSEIDON_output/TOI-1266 c/retrievals/results/

# %%
from POSEIDON.utility import read_retrieved_spectrum, plot_collection
from POSEIDON.visuals import plot_spectra_retrieved
from POSEIDON.corner import generate_cornerplot

wl, spec_low2, spec_low1, spec_median, spec_high1, spec_high2 = read_retrieved_spectrum(planet_name, model_name)

spectra_median = plot_collection(spec_median, wl, collection = [])
spectra_low1 = plot_collection(spec_low1, wl, collection = [])
spectra_low2 = plot_collection(spec_low2, wl, collection = [])
spectra_high1 = plot_collection(spec_high1, wl, collection = [])
spectra_high2 = plot_collection(spec_high2, wl, collection = [])

fig_spec = plot_spectra_retrieved(spectra_median, spectra_low2, spectra_low1,
                                  spectra_high1, spectra_high2, planet_name,
                                  data_new, R_to_bin = 100,
                                  data_labels = ['NIRSpec Prism'],
                                  figure_shape = 'wide', wl_axis = 'linear',
                                  plt_label = 'Simulated JWST Retrieval')

fig_corner = generate_cornerplot(planet, model)#, true_vals = [R_p/R_J, PT_params[0],
                                                #             log_X_params[0], log_X_params[1]])
# Out:
# Generating corner plot ...

# %%
#***** Define new model *****#

model_name_2 = '95%CO2 5%H2'

bulk_species = ['CO2']
param_species_2 = ['H2']  # H2 new chemical species added

# Create the model object
model_2 = define_model(model_name_2, bulk_species, param_species_2,
                       PT_profile = 'isotherm', cloud_model = 'cloud-free')

# Check the free parameters defining this model
print("Free parameters: " + str(model_2['param_names']))

#***** Set priors for new retrieval *****#

# Initialise prior type dictionary
prior_types_2 = {}

# Specify whether priors are linear, Gaussian, etc.
prior_types_2['T'] = 'uniform'
prior_types_2['R_p_ref'] = 'uniform'
prior_types_2['log_X'] = 'uniform'    # 'log_X' sets the same prior for all mixing ratios

# Initialise prior range dictionary
prior_ranges_2 = {}

# Specify prior ranges for each free parameter
prior_ranges_2['T'] = [100, 1000]
prior_ranges_2['R_p_ref'] = [0.85*R_p, 1.15*R_p]
prior_ranges_2['log_X'] = [-12, -1]   # 'log_X' sets the same prior for all mixing ratios

# Create prior object for retrieval
priors_2 = set_priors(planet, star, model_2, data, prior_types_2, prior_ranges_2)

#***** Read opacity data *****#

# Pre-interpolate the opacities
opac_2 = read_opacities(model_2, wl, opacity_treatment, T_fine, log_P_fine)

#***** Run atmospheric retrieval *****#

run_retrieval(planet, star, model_2, opac_2, data, priors_2, wl, P, P_ref, R = R,
              spectrum_type = 'transmission', sampling_algorithm = 'MultiNest',
              N_live = 400, verbose = True)
# Out:
# Free parameters: ['R_p_ref' 'T' 'log_H2']
# Reading in cross sections in opacity sampling mode...
# H2-H2 done
# CO2-H2 done
# CO2-CO2 done
# CO2 done
# Opacity pre-interpolation complete.
# POSEIDON now running '95%CO2 5%H2'
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  400
#  dimensionality =    3
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.989011
# Replacements:                                450
# Total Samples:                               455
# Nested Sampling ln(Z):               -410.896217
# Acceptance Rate:                        0.972763
# Replacements:                                500
# Total Samples:                               514
# Nested Sampling ln(Z):                233.908928
# Acceptance Rate:                        0.943396
# Replacements:                                550
# Total Samples:                               583
# Nested Sampling ln(Z):                814.877191
# Acceptance Rate:                        0.900901
# Replacements:                                600
# Total Samples:                               666
# Nested Sampling ln(Z):               1265.963357
# Acceptance Rate:                        0.868984
# Replacements:                                650
# Total Samples:                               748
# Nested Sampling ln(Z):               1698.855313
# Acceptance Rate:                        0.837321
# Replacements:                                700
# Total Samples:                               836
# Nested Sampling ln(Z):               2031.569163
# Acceptance Rate:                        0.789474
# Replacements:                                750
# Total Samples:                               950
# Nested Sampling ln(Z):               2270.733457
# Acceptance Rate:                        0.775946
# Replacements:                                800
# Total Samples:                              1031
# Nested Sampling ln(Z):               2429.609297
# Acceptance Rate:                        0.770626
# Replacements:                                850
# Total Samples:                              1103
# Nested Sampling ln(Z):               2571.698194
# Acceptance Rate:                        0.769231
# Replacements:                                900
# Total Samples:                              1170
# Nested Sampling ln(Z):               2671.133868
# Acceptance Rate:                        0.765512
# Replacements:                                950
# Total Samples:                              1241
# Nested Sampling ln(Z):               2779.140937
# Acceptance Rate:                        0.755858
# Replacements:                               1000
# Total Samples:                              1323
# Nested Sampling ln(Z):               2850.029363
# Acceptance Rate:                        0.751073
# Replacements:                               1050
# Total Samples:                              1398
# Nested Sampling ln(Z):               2899.651329
# Acceptance Rate:                        0.742240
# Replacements:                               1100
# Total Samples:                              1482
# Nested Sampling ln(Z):               2942.492428
# Acceptance Rate:                        0.740502
# Replacements:                               1150
# Total Samples:                              1553
# Nested Sampling ln(Z):               2971.080541
# Acceptance Rate:                        0.735294
# Replacements:                               1200
# Total Samples:                              1632
# Nested Sampling ln(Z):               2993.240617
# Acceptance Rate:                        0.736160
# Replacements:                               1250
# Total Samples:                              1698
# Nested Sampling ln(Z):               3017.855750
# Acceptance Rate:                        0.738636
# Replacements:                               1300
# Total Samples:                              1760
# Nested Sampling ln(Z):               3031.182256
# Acceptance Rate:                        0.732899
# Replacements:                               1350
# Total Samples:                              1842
# Nested Sampling ln(Z):               3046.640291
# Acceptance Rate:                        0.722767
# Replacements:                               1400
# Total Samples:                              1937
# Nested Sampling ln(Z):               3057.077205
# Acceptance Rate:                        0.712531
# Replacements:                               1450
# Total Samples:                              2035
# Nested Sampling ln(Z):               3066.837829
# Acceptance Rate:                        0.706547
# Replacements:                               1500
# Total Samples:                              2123
# Nested Sampling ln(Z):               3072.663407
# Acceptance Rate:                        0.701357
# Replacements:                               1550
# Total Samples:                              2210
# Nested Sampling ln(Z):               3078.492017
# Acceptance Rate:                        0.701754
# Replacements:                               1600
# Total Samples:                              2280
# Nested Sampling ln(Z):               3082.842791
# Acceptance Rate:                        0.702427
# Replacements:                               1650
# Total Samples:                              2349
# Nested Sampling ln(Z):               3085.817991
# Acceptance Rate:                        0.704517
# Replacements:                               1700
# Total Samples:                              2413
# Nested Sampling ln(Z):               3088.441864
# Acceptance Rate:                        0.704509
# Replacements:                               1750
# Total Samples:                              2484
# Nested Sampling ln(Z):               3090.436525
# Acceptance Rate:                        0.697404
# Replacements:                               1800
# Total Samples:                              2581
# Nested Sampling ln(Z):               3092.003142
# Acceptance Rate:                        0.700492
# Replacements:                               1850
# Total Samples:                              2641
# Nested Sampling ln(Z):               3093.335372
# Acceptance Rate:                        0.698786
# Replacements:                               1900
# Total Samples:                              2719
# Nested Sampling ln(Z):               3094.370487
# Acceptance Rate:                        0.694444
# Replacements:                               1950
# Total Samples:                              2808
# Nested Sampling ln(Z):               3095.241834
# Acceptance Rate:                        0.696864
# Replacements:                               2000
# Total Samples:                              2870
# Nested Sampling ln(Z):               3096.008188
# Acceptance Rate:                        0.694209
# Replacements:                               2050
# Total Samples:                              2953
# Nested Sampling ln(Z):               3096.698015
# Acceptance Rate:                        0.692384
# Replacements:                               2100
# Total Samples:                              3033
# Nested Sampling ln(Z):               3097.260722
# Acceptance Rate:                        0.691096
# Replacements:                               2150
# Total Samples:                              3111
# Nested Sampling ln(Z):               3097.690107
# Acceptance Rate:                        0.692042
# Replacements:                               2200
# Total Samples:                              3179
# Nested Sampling ln(Z):               3098.059385
# Acceptance Rate:                        0.689761
# Replacements:                               2250
# Total Samples:                              3262
# Nested Sampling ln(Z):               3098.383346
# Acceptance Rate:                        0.690276
# Replacements:                               2300
# Total Samples:                              3332
# Nested Sampling ln(Z):               3098.659059
# Acceptance Rate:                        0.687939
# Replacements:                               2350
# Total Samples:                              3416
# Nested Sampling ln(Z):               3098.891746
# Acceptance Rate:                        0.683371
# Replacements:                               2400
# Total Samples:                              3512
# Nested Sampling ln(Z):               3099.092206
# Acceptance Rate:                        0.682451
# Replacements:                               2450
# Total Samples:                              3590
# Nested Sampling ln(Z):               3099.260602
# Acceptance Rate:                        0.681385
# Replacements:                               2500
# Total Samples:                              3669
# Nested Sampling ln(Z):               3099.402032
# Acceptance Rate:                        0.680908
# Replacements:                               2550
# Total Samples:                              3745
# Nested Sampling ln(Z):               3099.524352
# Acceptance Rate:                        0.680094
# Replacements:                               2600
# Total Samples:                              3823
# Nested Sampling ln(Z):               3099.632745
# Acceptance Rate:                        0.681059
# Replacements:                               2650
# Total Samples:                              3891
# Nested Sampling ln(Z):               3099.728612
# Acceptance Rate:                        0.678392
# Replacements:                               2700
# Total Samples:                              3980
# Nested Sampling ln(Z):               3099.812443
# Acceptance Rate:                        0.676673
# Replacements:                               2750
# Total Samples:                              4064
# Nested Sampling ln(Z):               3099.886568
# Acceptance Rate:                        0.674211
# Replacements:                               2800
# Total Samples:                              4153
# Nested Sampling ln(Z):               3099.952149
# Acceptance Rate:                        0.675676
# Replacements:                               2850
# Total Samples:                              4218
# Nested Sampling ln(Z):               3100.010354
# Acceptance Rate:                        0.677412
# Replacements:                               2900
# Total Samples:                              4281
# Nested Sampling ln(Z):               3100.061966
# Acceptance Rate:                        0.677650
# Replacements:                               2941
# Total Samples:                              4340
# Nested Sampling ln(Z):               3100.099958
# POSEIDON retrieval finished in 0.28 hours
#  ln(ev)=   3100.4523203818071      +/-  0.10436799872289389
#  Total Likelihood Evaluations:         4340
#  Sampling finished. Exiting MultiNest
# Now generating 1000 sampled spectra and P-T profiles from the posterior distribution...
# This process will take approximately 4.8 minutes
# All done! Output files can be found in ./POSEIDON_output/TOI-1266 c/retrievals/results/

# %%
from POSEIDON.utility import read_retrieved_spectrum, plot_collection
from POSEIDON.visuals import plot_spectra_retrieved
from POSEIDON.corner import generate_cornerplot

wl, spec_low2, spec_low1, spec_median, spec_high1, spec_high2 = read_retrieved_spectrum(planet_name, model_name_2)

spectra_median = plot_collection(spec_median, wl, collection = spectra_median)
spectra_low1 = plot_collection(spec_low1, wl, collection = spectra_low1)
spectra_low2 = plot_collection(spec_low2, wl, collection = spectra_low2)
spectra_high1 = plot_collection(spec_high1, wl, collection = spectra_high1)
spectra_high2 = plot_collection(spec_high2, wl, collection = spectra_high2)

fig_spec = plot_spectra_retrieved(spectra_median, spectra_low2, spectra_low1,
                                  spectra_high1, spectra_high2, planet_name,
                                  data_new, R_to_bin = 100,
                                  data_labels = ['NIRSpec Prism'],
                                  figure_shape = 'wide', wl_axis = 'linear',
                                  plt_label = 'Simulated JWST Retrieval')

fig_corner = generate_cornerplot(planet, model)#, true_vals = [R_p/R_J, PT_params[0],
                                                #             log_X_params[0], log_X_params[1]])
# Out:
# Generating corner plot ...
