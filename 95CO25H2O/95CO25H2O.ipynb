# %%
from POSEIDON.core import create_star, create_planet
from POSEIDON.constants import R_J, R_Sun

R_s = 0.42*R_Sun
T_s = 3600
log_g_s = 4.85
Met_s = -0.5

star = create_star(R_s, T_s, log_g_s, Met_s)

planet_name = 'TOI-1266 c'
R_p = 0.139*R_J
T_eq = 345.87
g_p = 8.87769

planet = create_planet(planet_name, R_p, gravity=g_p, T_eq=T_eq)

# %%
from POSEIDON.core import define_model, read_opacities, make_atmosphere, compute_spectrum
import numpy as np

model_name = '95%CO2 5% H2O'

bulk_species = ['CO2']
param_species = ['H2O', 'CH4']

# Create the model object
model = define_model(model_name, bulk_species, param_species,
                     PT_profile = 'isotherm', cloud_model = 'cloud-free')

# Specify the pressure grid of the atmosphere
P_min = 1.0e-7    # 0.1 ubar
P_max = 100       # 100 bar
N_layers = 100    # 100 layers

P = np.logspace(np.log10(P_max), np.log10(P_min), N_layers)

# Specify the reference pressure and radius
P_ref = 1         # 1 bar
R_p_ref = R_p         # Radius at reference pressure

# Provide a specific set of model parameters for the atmosphere
PT_params = np.array([T_eq])              # Assume terminator temperature is T_eq
log_X_params = np.array([-1.5228, -1.6989])   # CO2 H2 log abundances in model
                    #N2% 3.5
# Generate the atmosphere
atmosphere = make_atmosphere(planet, model, P, P_ref, R_p_ref, PT_params, log_X_params)

# %%
from POSEIDON.core import wl_grid_constant_R

wl_min = 0.5
wl_max = 5.5
R = 10000

wl = wl_grid_constant_R(wl_min, wl_max, R)

#***Reading Opacities***#

opacity_treatment = 'opacity_sampling'

# Define fine temperature grid (K)
T_fine_min = 100     # Same as prior range for T
T_fine_max = 1000    # Same as prior range for T
T_fine_step = 10     # 10 K steps are a good tradeoff between accuracy and RAM

T_fine = np.arange(T_fine_min, (T_fine_max + T_fine_step), T_fine_step)

# Define fine pressure grid (log10(P/bar))
log_P_fine_min = -6   # 1 ubar is the lowest pressure in the opacity database
log_P_fine_max = 2    # 100 bar is the highest pressure in the opacity database
log_P_fine_step = 0.2   # 0.2 dex steps are a good tradeoff between accuracy and RAM

log_P_fine = np.arange(log_P_fine_min, (log_P_fine_max + log_P_fine_step),
                       log_P_fine_step)

# Pre-interpolate the opacities (note: model wavelength range was initialised in cell above)
opac = read_opacities(model, wl, opacity_treatment, T_fine, log_P_fine)
# Out:
# Reading in cross sections in opacity sampling mode...
# CO2-CO2 done
# CO2-CH4 done
# CO2 done
# H2O done
# CH4 done
# Opacity pre-interpolation complete.

# %%
from POSEIDON.visuals import plot_spectra
from POSEIDON.utility import plot_collection

spectrum = compute_spectrum(planet, star, model, atmosphere, opac, wl,
                            spectrum_type = 'transmission')
spectra = []

spectra = plot_collection(spectrum, wl, collection = spectra)

fig_spec = plot_spectra(spectra, planet, R_to_bin = 100, 
                        plot_full_res=True, figure_shape='wide', spectra_labels=['CO2 with 5% H2O-Model'], plt_label='Forward Model for Proposal', wl_axis='linear')

# %%
#####TEST CELL FOR H2O feature

# Define new mixing ratio array with a low CO2 abundance
log_X_params_no_CH4 = np.array([-100])  # log(H2O)

# Create a new atmosphere without CO2
atmosphere_no_CH4 = make_atmosphere(planet, model, P, P_ref, R_p_ref,
                                    PT_params, log_X_params_no_CH4)

# Generate the new transmission spectrum
spectrum_no_CH4 = compute_spectrum(planet, star, model, atmosphere_no_CH4,
                                   opac, wl, spectrum_type = 'transmission')

# Add the spectrum we want to plot to our existing plot collection
spectra = plot_collection(spectrum_no_CH4, wl, collection = spectra)

# Produce figure
fig_spec = plot_spectra(spectra, planet, R_to_bin = 100,
                        spectra_labels = ['CO2 with 5% H2O', 'No H$_2$O'], figure_shape='wide', plot_full_res=True, wl_axis='linear')
# high mean molecular weight CO2 makes low transit depth.

# %%
# Do not run below cell if you ran cell for identifying molecular feature

# %%
# for j in range(1):
#     for i in range(len(spectra[0][1])):
#         print(spectra[0][j+1][i],' ', spectra[0][j][i])

instrument = 'NIRSpec Prism'

outfile = open(planet_name + '_JWST_' + instrument + "_" + bulk_species[0] + param_species[0] + "_spectra_file.txt","w")
for j in range(1): # wl in column 1 and T.D in column 2
    for i in range(len(spectra[0][1])):
        outfile.writelines(str(spectra[0][j+1][i]))
        outfile.writelines('\t')
        outfile.writelines(str(spectra[0][j][i]))
        outfile.writelines('\n')
outfile.close()

# %%
# change kernel to pandexo

# %%
# assign a core to numpy
import os
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'
os.environ['CBLAS_NUM_THREADS'] = '1'

# %%
# import necessary modules
import warnings
warnings.filterwarnings('ignore')
import pandexo.engine.justdoit as jdi
import pandexo.engine.justplotit as jpi
import astropy
import pickle as pk
import numpy as np
import scipy.constants as sc

# %%
# This is used to write the data with specific order
def write_data(planet_dir, wl_data, bin_size, spectrum, err_data, 
               instrument, N_trans, NRS_detector, NIRISS_order, model):
    
    if (instrument == 'NIRISS SOSS'): # for NIRISS SOSS order #
        suffix = '_Ord' + str(NIRISS_order)
    elif (('NIRSpec G' in instrument) and ('H' in instrument)): #for NIRSpec G H detector
        suffix = '_NRS' + str(NRS_detector)
    else: #for all other instruments, no suffix
        suffix = ''
    
    f = open(planet_dir + '/' + planet_name + '_' + model + '_' +
             instrument + suffix + '_N_trans_' + str(N_trans) + '.dat', 'w')
    
    for i in range(len(wl_data)): # f for float, e for scientific notation
        f.write('%.8f %.8f %.8e %.8e \n' %(wl_data[i], bin_size[i], spectrum[i], err_data[i]))
    
    f.close()

# %%
#planet and instrument properties

planet_name = 'TOI-1266 c'
model = 'CO2+5%H2O'

N_trans = 1 # no. of transits

instrument = 'NIRSpec Prism' #other instruments such as NIRISS SOSS, MIRI LRS
NIRISS_order = 1     # 1st or 2nd order for NIRISS SOSS only

# ***Create output directories***

# Specify desired paths of output directories to be created

output_dir = './data'
planet_dir = output_dir + '/' + planet_name

# create main output directory named 'data' which will include planet directory
if (os.path.exists(output_dir) == False):
    os.mkdir(output_dir)
    
if (os.path.exists(planet_dir) == False):
    os.mkdir(planet_dir)
    
# check the directory once

# %%
# PandExo settings

Trans_duration = 2.05 # Transit duration of TOI-1266 c, in hours, from ExoMast

#Loads in empty exoplanet dictionary for pandexo input, to edit planetary params
exo_dict = jdi.load_exo_dict() 

exo_dict['observation']['sat_level'] = 80                # Saturation level in percent of full well
exo_dict['observation']['sat_unit'] = '%'                 # Other option = 'e' for electrons
exo_dict['observation']['noccultations'] = N_trans        # Number of transits
exo_dict['observation']['R'] = None                       # Fixed binning. I usually suggest ZERO binning.. you can always bin later
exo_dict['observation']['baseline'] = 3.8*60.0*60.0        # Time spent observing out of transit, make sure to specify units
exo_dict['observation']['baseline_unit'] = 'total'         # Total observing time, other option 'frac' = in/out
exo_dict['observation']['noise_floor'] = 10                # This can be a fixed level or it can be a filepath

# The stellar properties below are for L 98- 59 b from ExoMast and SIMBAD (except for stellar metallicity)
exo_dict['star']['type'] = 'phoenix'        # Phoenix or user (if you have your own)
exo_dict['star']['mag'] = 8.8             # Magnitude of the system
exo_dict['star']['ref_wave'] = 2.22         # For J mag = 1.25, H = 1.6, K =2.22.. etc (all in micron)
exo_dict['star']['temp'] = 3600             # (K)
exo_dict['star']['metal'] = 0.0             # ALWAYS USE 0.0 FOR PHOENIX MODELS (there's a bug at non-solar metallicities)
exo_dict['star']['logg'] = 4.85             # Log surface gravity (cgs)
exo_dict['star']['radius'] = 0.42
exo_dict['star']['r_unit'] = 'R_sun'

exo_dict['planet']['type'] = 'user'#tells pandexo you want a user defined transit depth, can be user defined check JWST_Running_Pandexo_w_ExoMAST.ipynb
exo_dict['planet']['exopath'] = 'TOI-1266 c_JWST_NIRSpec Prism_CO2H2O_spectra_file.txt'
exo_dict['planet']['w_unit'] = 'um'            # Other options include "um","nm" ,"Angs", "secs" (for phase curves)
exo_dict['planet']['radius'] = 0.139               # We're just using a flat spectrum here, will scatter errors about a model later
exo_dict['planet']['r_unit'] = 'R_jup'
exo_dict['planet']['f_unit'] = 'rp^2/r*^2'     #this is what you would do for primary transit 

exo_dict['planet']['transit_duration'] = Trans_duration*60*60.0     # Transit duration in seconds
exo_dict['planet']['td_unit'] = 's'

# %%
#***** Begin PandExo run *****#
print('Running PandExo for ' + instrument)

inst_dict = jdi.load_mode_dict(instrument)

# if (instrument == 'NIRSpec Prism'):
#     inst_dict["configuration"]["detector"]["subarray"] = 'sub2048'
# #     inst_dict["strategy"]["order"] = NIRISS_order

print(inst_dict["configuration"]["detector"]["subarray"])
print(inst_dict["configuration"]["instrument"]["filter"])
# Out:
# Running PandExo for NIRSpec Prism
# sub512
# clear

# %%
result = jdi.run_pandexo(exo_dict, inst_dict, output_path = planet_dir, output_file = planet_name + '_'+ instrument+ '_95CO25H2O' + '.p')

print(result['timing'])
print()
print(result['warning'])
# Out:
# Running Single Case w/ User Instrument Dict
# Optimization Reqested: Computing Duty Cycle
# Finished Duty Cycle Calc
# Starting Out of Transit Simulation
# End out of Transit
# Starting In Transit Simulation
# End In Transit
# {'Transit Duration': 2.05, 'Seconds per Frame': 0.22616, 'Time/Integration incl reset (sec)': 0.67848, 'APT: Num Groups per Integration': 2, 'Num Integrations Out of Transit': 9287, 'Num Integrations In Transit': 10878, 'APT: Num Integrations per Occultation': 20165, 'Observing Efficiency (%)': 33.33333333333333, 'Transit+Baseline, no overhead (hrs)': 3.800430333333333, 'Number of Transits': 1}
#
# {'Group Number Too Low?': 'All good', 'Group Number Too High?': 'All good', 'Non linear?': 'All good', 'Saturated?': 'Full saturation:\n There are 115 pixels saturated at the end of the first group. These pixels cannot be recovered.', '% full well high?': 'All good', 'Num Groups Reset?': 'NGROUPS<2SET TO NGROUPS=2'}

# %%
out = pk.load((open(planet_dir + '/' + planet_name + '_'+ instrument + '_95CO25H2O' +'.p', 'rb')))

wl_data, ydata, err_data = jpi.jwst_1d_spec(out, num_tran=N_trans, plot=True, model=True)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>
#   <div id="68f64525-ee91-4aef-8e71-9076b61b4e24" data-root-id="p1002" style="display: contents;"></div>

# %%
half_width = 0.5 * np.diff(wl_data[0], append=np.array([wl_data[0][-1] + (wl_data[0][-1] - wl_data[0][-2])]))
keep_err = 1e-3 # Error criteria to keep data point (< 1000 ppm), trims things like data in band gaps
wl_data_out = wl_data[0][np.where(err_data[0]<= keep_err)]
half_width_out = half_width[np.where(err_data[0]<=keep_err)]
ydata_out = ydata[0][np.where(err_data[0]<=keep_err)]
err_data_out = err_data[0][np.where(err_data[0]<=keep_err)]

# %%
#For NIRSpec
if (('NIRSpec G' in instrument) and ('H' in instrument)):
    NRS_1_idx = np.argwhere(wl_data_out < band_gaps[instrument])
    NRS_2_idx = np.argwhere(wl_data_out > band_gaps[instrument])
    
    wl_NRS_1 = wl_data_out[NRS_1_idx]
    half_width_NRS_1 = half_width_out[NRS_1_idx]
    ydata_NRS_1 = ydata_out[NRS_1_idx]
    err_data_NRS_1 = err_data_out[NRS_1_idx]

    wl_NRS_2 = wl_data_out[NRS_2_idx]
    half_width_NRS_2 = half_width_out[NRS_2_idx]
    ydata_NRS_2 = ydata_out[NRS_2_idx]
    err_data_NRS_2 = err_data_out[NRS_2_idx]
    
    NRS_detector = 1
    write_data(planet_dir, wl_NRS_1, half_width_NRS_1, ydata_NRS_1, err_data_NRS_1, instrument, N_trans, NRS_detector, NIRISS_order, model)

    NRS_detector = 2
    write_data(planet_dir, wl_NRS_2, half_width_NRS_2, ydata_NRS_2, err_data_NRS_2, instrument, N_trans, NRS_detector, NIRISS_order, model)
    
else:
    NRS_detector = 0
    
    write_data(planet_dir, wl_data_out, half_width_out, ydata_out, err_data_out, instrument, N_trans, NRS_detector, NIRISS_order, model)

# %%
print('Mean ' +str(1e6*np.mean(err_data_out)) + ' ppm')
# Out:
# Mean 123.48934802770036 ppm

# %%
# Change kernel to POSEIDON

# %%
from POSEIDON.core import load_data, wl_grid_constant_R
from POSEIDON.visuals import plot_data
# Out:
# /home/swaroop/anaconda3/envs/poseidon/lib/python3.9/site-packages/pysynphot/locations.py:345: UserWarning: Extinction files not found in /home/swaroop/sample/grp/redcat/trds/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))
# /home/swaroop/POSEIDON/POSEIDON/absorption.py:1466: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def store_Rayleigh_eta_LBL(wl_model, chemical_species):

# %%
planet_name = 'TOI-1266 c'

wl_min = 0.5
wl_max = 5.5

R = 10000

wl = wl_grid_constant_R(wl_min, wl_max, R)

data_dir = './data/' + planet_name

datasets = [planet_name + '_CO2+5%H2O_NIRSpec Prism_N_trans_1.dat']
#This datasets is obtained from pandexo snippet

instruments = ['JWST_NIRSpec_Prism']

data = load_data(data_dir, datasets, instruments, wl)

fig_data = plot_data(data, planet_name, wl_min, wl_max, wl_axis='linear',
                     data_labels = ['NIRSpec_Prism'], 
                     plt_label = 'PandExo Output')

# %%
#run first four cells to call the params again

# %%
from POSEIDON.instrument import generate_syn_data_from_file
N_trans = [10]

R_to_bin = [100]

generate_syn_data_from_file(planet, wl, spectrum, data_dir, data, R_to_bin = R_to_bin, N_trans=N_trans, label=model_name, Gauss_scatter=True)
# Out:
# Creating synthetic data
# JWST_NIRSpec_Prism

# %%
# Now synthetic data (pandexo simulated data is scattered around poseidon model using plot from poseidon) 
datasets_new = [planet_name + '_SYNTHETIC_JWST_NIRSpec_Prism_' + model_name + '_N_trans_' + str(N_trans[0]) + '.dat',]

#datasets_new = ['L 98-59 b_SYNTHETIC_JWST_MIRI_LRS_Venus-like_N_trans_1.dat']
data_new = load_data(data_dir, datasets_new, instruments, wl)

spectra = []

spectra = plot_collection(spectrum, wl, collection = spectra)

fig_spec = plot_spectra(spectra, planet, data_properties=data_new, R_to_bin=100, plot_full_res=False, show_data = True, figure_shape='wide', wl_min=0.6, wl_max=5.3, wl_axis='linear')

# %%
from POSEIDON.core import define_model
model_name = 'retr1'

bulk_species = ['CO2']
param_species = ['H2O','CH4']

# Create the model object
model = define_model(model_name, bulk_species, param_species,
                     PT_profile = 'isotherm', cloud_model = 'cloud-free')

# %%
from POSEIDON.core import read_opacities
import numpy as np

opacity_treatment = 'opacity_sampling'

# Define fine temperature grid (K)
T_fine_min = 100     # Same as prior range for T
T_fine_max = 1000    # Same as prior range for T
T_fine_step = 10     # 10 K steps are a good tradeoff between accuracy and RAM

T_fine = np.arange(T_fine_min, (T_fine_max + T_fine_step), T_fine_step)

# Define fine pressure grid (log10(P/bar))
log_P_fine_min = -6   # 1 ubar is the lowest pressure in the opacity database
log_P_fine_max = 2    # 100 bar is the highest pressure in the opacity database
log_P_fine_step = 0.2   # 0.2 dex steps are a good tradeoff between accuracy and RAM

log_P_fine = np.arange(log_P_fine_min, (log_P_fine_max + log_P_fine_step),
                       log_P_fine_step)

# Pre-interpolate the opacities (note: model wavelength range was initialised in cell above)
opac = read_opacities(model, wl, opacity_treatment, T_fine, log_P_fine)
# Out:
# Reading in cross sections in opacity sampling mode...
# CO2-CO2 done
# CO2-CH4 done
# CO2 done
# H2O done
# CH4 done
# Opacity pre-interpolation complete.

# %%
from POSEIDON.core import set_priors

prior_types = {}
prior_ranges = {}

prior_types['T'] = 'uniform'
prior_types['R_p_ref'] = 'uniform'
prior_types['log_X'] = 'uniform'

prior_ranges['T'] = [100, 1000]
prior_ranges['R_p_ref'] = [0.85*R_p, 1.15*R_p]
prior_ranges['log_X'] = [-12,-1] 

priors = set_priors(planet, star, model, data_new, prior_types, prior_ranges)

# %%
from POSEIDON.retrieval import run_retrieval

run_retrieval(planet, star, model, opac, data_new, priors, wl, P, P_ref, 
             R=R, spectrum_type='transmission', sampling_algorithm=
              'MultiNest', N_live = 400, verbose=True, resume = False)
# Out:
# POSEIDON now running 'retr1'
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  400
#  dimensionality =    4
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.995575
# Replacements:                                450
# Total Samples:                               452
# Nested Sampling ln(Z):             -55928.128034
# Acceptance Rate:                        0.980392
# Replacements:                                500
# Total Samples:                               510
# Nested Sampling ln(Z):             -42849.760988
# Acceptance Rate:                        0.953206
# Replacements:                                550
# Total Samples:                               577
# Nested Sampling ln(Z):             -34878.963154
# Acceptance Rate:                        0.909091
# Replacements:                                600
# Total Samples:                               660
# Nested Sampling ln(Z):             -27090.926299
# Acceptance Rate:                        0.887978
# Replacements:                                650
# Total Samples:                               732
# Nested Sampling ln(Z):             -21010.243068
# Acceptance Rate:                        0.875000
# Replacements:                                700
# Total Samples:                               800
# Nested Sampling ln(Z):             -16376.272921
# Acceptance Rate:                        0.852273
# Replacements:                                750
# Total Samples:                               880
# Nested Sampling ln(Z):             -12190.221599
# Acceptance Rate:                        0.841220
# Replacements:                                800
# Total Samples:                               951
# Nested Sampling ln(Z):              -9446.146507
# Acceptance Rate:                        0.821256
# Replacements:                                850
# Total Samples:                              1035
# Nested Sampling ln(Z):              -7613.422788
# Acceptance Rate:                        0.812274
# Replacements:                                900
# Total Samples:                              1108
# Nested Sampling ln(Z):              -5333.853692
# Acceptance Rate:                        0.804403
# Replacements:                                950
# Total Samples:                              1181
# Nested Sampling ln(Z):              -3832.349148
# Acceptance Rate:                        0.798722
# Replacements:                               1000
# Total Samples:                              1252
# Nested Sampling ln(Z):              -2516.183999
# Acceptance Rate:                        0.799695
# Replacements:                               1050
# Total Samples:                              1313
# Nested Sampling ln(Z):              -1251.762900
# Acceptance Rate:                        0.797679
# Replacements:                               1100
# Total Samples:                              1379
# Nested Sampling ln(Z):               -528.971979
# Acceptance Rate:                        0.793103
# Replacements:                               1150
# Total Samples:                              1450
# Nested Sampling ln(Z):                192.975366
# Acceptance Rate:                        0.791557
# Replacements:                               1200
# Total Samples:                              1516
# Nested Sampling ln(Z):                549.649486
# Acceptance Rate:                        0.787650
# Replacements:                               1250
# Total Samples:                              1587
# Nested Sampling ln(Z):                882.628093
# Acceptance Rate:                        0.781250
# Replacements:                               1300
# Total Samples:                              1664
# Nested Sampling ln(Z):               1097.284211
# Acceptance Rate:                        0.776308
# Replacements:                               1350
# Total Samples:                              1739
# Nested Sampling ln(Z):               1317.539312
# Acceptance Rate:                        0.767965
# Replacements:                               1400
# Total Samples:                              1823
# Nested Sampling ln(Z):               1480.547667
# Acceptance Rate:                        0.765980
# Replacements:                               1450
# Total Samples:                              1893
# Nested Sampling ln(Z):               1599.384891
# Acceptance Rate:                        0.764137
# Replacements:                               1500
# Total Samples:                              1963
# Nested Sampling ln(Z):               1720.541356
# Acceptance Rate:                        0.754258
# Replacements:                               1550
# Total Samples:                              2055
# Nested Sampling ln(Z):               1782.577542
# Acceptance Rate:                        0.743149
# Replacements:                               1600
# Total Samples:                              2153
# Nested Sampling ln(Z):               1838.540852
# Acceptance Rate:                        0.736278
# Replacements:                               1650
# Total Samples:                              2241
# Nested Sampling ln(Z):               1873.548582
# Acceptance Rate:                        0.734659
# Replacements:                               1700
# Total Samples:                              2314
# Nested Sampling ln(Z):               1907.981457
# Acceptance Rate:                        0.731300
# Replacements:                               1750
# Total Samples:                              2393
# Nested Sampling ln(Z):               1930.569599
# Acceptance Rate:                        0.729040
# Replacements:                               1800
# Total Samples:                              2469
# Nested Sampling ln(Z):               1949.624348
# Acceptance Rate:                        0.728346
# Replacements:                               1850
# Total Samples:                              2540
# Nested Sampling ln(Z):               1962.661889
# Acceptance Rate:                        0.725745
# Replacements:                               1900
# Total Samples:                              2618
# Nested Sampling ln(Z):               1975.680268
# Acceptance Rate:                        0.723294
# Replacements:                               1950
# Total Samples:                              2696
# Nested Sampling ln(Z):               1987.359230
# Acceptance Rate:                        0.722022
# Replacements:                               2000
# Total Samples:                              2770
# Nested Sampling ln(Z):               1997.232305
# Acceptance Rate:                        0.718542
# Replacements:                               2050
# Total Samples:                              2853
# Nested Sampling ln(Z):               2004.704112
# Acceptance Rate:                        0.716724
# Replacements:                               2100
# Total Samples:                              2930
# Nested Sampling ln(Z):               2010.744650
# Acceptance Rate:                        0.714761
# Replacements:                               2150
# Total Samples:                              3008
# Nested Sampling ln(Z):               2017.352967
# Acceptance Rate:                        0.712205
# Replacements:                               2200
# Total Samples:                              3089
# Nested Sampling ln(Z):               2023.063608
# Acceptance Rate:                        0.709779
# Replacements:                               2250
# Total Samples:                              3170
# Nested Sampling ln(Z):               2027.274291
# Acceptance Rate:                        0.707910
# Replacements:                               2300
# Total Samples:                              3249
# Nested Sampling ln(Z):               2030.743711
# Acceptance Rate:                        0.704648
# Replacements:                               2350
# Total Samples:                              3335
# Nested Sampling ln(Z):               2034.063852
# Acceptance Rate:                        0.700117
# Replacements:                               2400
# Total Samples:                              3428
# Nested Sampling ln(Z):               2037.233952
# Acceptance Rate:                        0.698802
# Replacements:                               2450
# Total Samples:                              3506
# Nested Sampling ln(Z):               2039.702101
# Acceptance Rate:                        0.695410
# Replacements:                               2500
# Total Samples:                              3595
# Nested Sampling ln(Z):               2042.312153
# Acceptance Rate:                        0.693689
# Replacements:                               2550
# Total Samples:                              3676
# Nested Sampling ln(Z):               2043.853253
# Acceptance Rate:                        0.692779
# Replacements:                               2600
# Total Samples:                              3753
# Nested Sampling ln(Z):               2045.368960
# Acceptance Rate:                        0.691545
# Replacements:                               2650
# Total Samples:                              3832
# Nested Sampling ln(Z):               2046.782644
# Acceptance Rate:                        0.689831
# Replacements:                               2700
# Total Samples:                              3914
# Nested Sampling ln(Z):               2048.051391
# Acceptance Rate:                        0.687500
# Replacements:                               2750
# Total Samples:                              4000
# Nested Sampling ln(Z):               2049.096854
# Acceptance Rate:                        0.685938
# Replacements:                               2800
# Total Samples:                              4082
# Nested Sampling ln(Z):               2049.938535
# Acceptance Rate:                        0.684932
# Replacements:                               2850
# Total Samples:                              4161
# Nested Sampling ln(Z):               2050.672057
# Acceptance Rate:                        0.683640
# Replacements:                               2900
# Total Samples:                              4242
# Nested Sampling ln(Z):               2051.325916
# Acceptance Rate:                        0.679567
# Replacements:                               2950
# Total Samples:                              4341
# Nested Sampling ln(Z):               2051.846676
# Acceptance Rate:                        0.678273
# Replacements:                               3000
# Total Samples:                              4423
# Nested Sampling ln(Z):               2052.253957
# Acceptance Rate:                        0.678079
# Replacements:                               3050
# Total Samples:                              4498
# Nested Sampling ln(Z):               2052.587742
# Acceptance Rate:                        0.673474
# Replacements:                               3100
# Total Samples:                              4603
# Nested Sampling ln(Z):               2052.878461
# Acceptance Rate:                        0.671069
# Replacements:                               3150
# Total Samples:                              4694
# Nested Sampling ln(Z):               2053.128741
# Acceptance Rate:                        0.670017
# Replacements:                               3200
# Total Samples:                              4776
# Nested Sampling ln(Z):               2053.359941
# Acceptance Rate:                        0.670103
# Replacements:                               3250
# Total Samples:                              4850
# Nested Sampling ln(Z):               2053.577241
# Acceptance Rate:                        0.669643
# Replacements:                               3300
# Total Samples:                              4928
# Nested Sampling ln(Z):               2053.772928
# Acceptance Rate:                        0.664814
# Replacements:                               3350
# Total Samples:                              5039
# Nested Sampling ln(Z):               2053.952230
# Acceptance Rate:                        0.661479
# Replacements:                               3400
# Total Samples:                              5140
# Nested Sampling ln(Z):               2054.110083
# Acceptance Rate:                        0.658146
# Replacements:                               3450
# Total Samples:                              5242
# Nested Sampling ln(Z):               2054.252924
# Acceptance Rate:                        0.655063
# Replacements:                               3500
# Total Samples:                              5343
# Nested Sampling ln(Z):               2054.385940
# Acceptance Rate:                        0.652094
# Replacements:                               3550
# Total Samples:                              5444
# Nested Sampling ln(Z):               2054.509627
# Acceptance Rate:                        0.648766
# Replacements:                               3600
# Total Samples:                              5549
# Nested Sampling ln(Z):               2054.620456
# Acceptance Rate:                        0.645675
# Replacements:                               3650
# Total Samples:                              5653
# Nested Sampling ln(Z):               2054.720018
# Acceptance Rate:                        0.644599
# Replacements:                               3700
# Total Samples:                              5740
# Nested Sampling ln(Z):               2054.810384
# Acceptance Rate:                        0.643666
# Replacements:                               3750
# Total Samples:                              5826
# Nested Sampling ln(Z):               2054.893894
# Acceptance Rate:                        0.640918
# Replacements:                               3800
# Total Samples:                              5929
# Nested Sampling ln(Z):               2054.970758
# Acceptance Rate:                        0.640492
# Replacements:                               3850
# Total Samples:                              6011
# Nested Sampling ln(Z):               2055.041043
# Acceptance Rate:                        0.639030
# Replacements:                               3900
# Total Samples:                              6103
# Nested Sampling ln(Z):               2055.104489
# Acceptance Rate:                        0.635252
# Replacements:                               3950
# Total Samples:                              6218
# Nested Sampling ln(Z):               2055.162226
# Acceptance Rate:                        0.634115
# Replacements:                               4000
# Total Samples:                              6308
# Nested Sampling ln(Z):               2055.214708
# Acceptance Rate:                        0.634101
# Replacements:                               4050
# Total Samples:                              6387
# Nested Sampling ln(Z):               2055.261685
# Acceptance Rate:                        0.630091
# Replacements:                               4100
# Total Samples:                              6507
# Nested Sampling ln(Z):               2055.303868
# Acceptance Rate:                        0.629169
# Replacements:                               4150
# Total Samples:                              6596
# Nested Sampling ln(Z):               2055.341865
# Acceptance Rate:                        0.627521
# Replacements:                               4200
# Total Samples:                              6693
# Nested Sampling ln(Z):               2055.376065
# Acceptance Rate:                        0.624541
# Replacements:                               4250
# Total Samples:                              6805
# Nested Sampling ln(Z):               2055.407096
# Acceptance Rate:                        0.622377
# Replacements:                               4300
# Total Samples:                              6909
# Nested Sampling ln(Z):               2055.434969
# Acceptance Rate:                        0.620188
# Replacements:                               4350
# Total Samples:                              7014
# Nested Sampling ln(Z):               2055.460070
# Acceptance Rate:                        0.617804
# Replacements:                               4400
# Total Samples:                              7122
# Nested Sampling ln(Z):               2055.482763
# Acceptance Rate:                        0.617006
# Replacements:                               4419
# Total Samples:                              7162
# Nested Sampling ln(Z):               2055.490799
#  ln(ev)=   2055.7026100768771      +/-  0.13237246691627860
# POSEIDON retrieval finished in 0.41 hours
#  Total Likelihood Evaluations:         7162
#  Sampling finished. Exiting MultiNest
# Now generating 1000 sampled spectra and P-T profiles from the posterior distribution...
# This process will take approximately 3.6 minutes
# All done! Output files can be found in ./POSEIDON_output/TOI-1266 c/retrievals/results/

# %%
from POSEIDON.utility import read_retrieved_spectrum, plot_collection
from POSEIDON.visuals import plot_spectra_retrieved
from POSEIDON.corner import generate_cornerplot

wl, spec_low2, spec_low1, spec_median, spec_high1, spec_high2 = read_retrieved_spectrum(planet_name, model_name)

spectra_median = plot_collection(spec_median, wl, collection = [])
spectra_low1 = plot_collection(spec_low1, wl, collection = [])
spectra_low2 = plot_collection(spec_low2, wl, collection = [])
spectra_high1 = plot_collection(spec_high1, wl, collection = [])
spectra_high2 = plot_collection(spec_high2, wl, collection = [])

fig_spec = plot_spectra_retrieved(spectra_median, spectra_low2, spectra_low1,
                                  spectra_high1, spectra_high2, planet_name,
                                  data_new, R_to_bin = 100,
                                  data_labels = ['NIRSpec Prism'],
                                  figure_shape = 'wide', wl_axis = 'linear',
                                  plt_label = 'Simulated JWST Retrieval')

fig_corner = generate_cornerplot(planet, model)#, true_vals = [R_p/R_J, PT_params[0],
                                                #             log_X_params[0], log_X_params[1]])
# Out:
# Generating corner plot ...

# %%
#TESTING H2O Detection

model_name_2 = 'retr2'

bulk_species_2 = ['CO2']
param_species_2 = ['CH4']

# Create the model object
model_2 = define_model(model_name_2, bulk_species_2, param_species_2,
                       PT_profile = 'isotherm', cloud_model = 'cloud-free')

opac_2 = read_opacities(model_2, wl, opacity_treatment, T_fine, log_P_fine)

prior_types_2 = {}

# Specify whether priors are linear, Gaussian, etc.
prior_types_2['T'] = 'uniform'
prior_types_2['R_p_ref'] = 'uniform'
prior_types_2['log_X'] = 'uniform'    # 'log_X' sets the same prior for all mixing ratios

# Initialise prior range dictionary
prior_ranges_2 = {}

# Specify prior ranges for each free parameter
prior_ranges_2['T'] = [100, 1000]
prior_ranges_2['R_p_ref'] = [0.85*R_p, 1.15*R_p]
prior_ranges_2['log_X'] = [-12, -1]   # 'log_X' sets the same prior for all mixing ratios

# Create prior object for retrieval
priors_2 = set_priors(planet, star, model_2, data_new, prior_types_2, prior_ranges_2)

#***** Run atmospheric retrieval *****#

run_retrieval(planet, star, model_2, opac_2, data_new, priors_2, wl, P, P_ref, 
             R=R, spectrum_type='transmission', sampling_algorithm=
              'MultiNest', N_live = 400, verbose=True, resume = False)
# Out:
# Reading in cross sections in opacity sampling mode...
# CO2-CO2 done
# CO2-CH4 done
# CO2 done
# CH4 done
# Opacity pre-interpolation complete.
# POSEIDON now running 'retr2'
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  400
#  dimensionality =    3
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.991189
# Replacements:                                450
# Total Samples:                               454
# Nested Sampling ln(Z):             -54270.932759
# ERROR: Interrupt received: Terminating
# Exception ignored on calling ctypes callback function: <function run.<locals>.loglike at 0x7fb5d9695430>
# Traceback (most recent call last):
#   File "/home/swaroop/anaconda3/envs/poseidon/lib/python3.9/site-packages/pymultinest/run.py", line 221, in loglike
#     return LogLikelihood(cube, ndim, nparams)
#   File "/home/swaroop/POSEIDON/POSEIDON/retrieval.py", line 828, in LogLikelihood
#     ymodel, spectrum, _ = forward_model(cube, planet, star, model, opac, data,
#   File "/home/swaroop/POSEIDON/POSEIDON/retrieval.py", line 350, in forward_model
#     spectrum = compute_spectrum(planet, star, model, atmosphere, opac, wl,
#   File "/home/swaroop/POSEIDON/POSEIDON/core.py", line 1167, in compute_spectrum
#     spectrum = TRIDENT(P, r, r_up, r_low, dr, wl, kappa_clear, kappa_cloud,
#   File "/home/swaroop/POSEIDON/POSEIDON/transmission.py", line 844, in TRIDENT
#     tau_vert = compute_tau_vert(N_phi, N_layers, N_zones, N_wl, j_sector,
#   File "/home/swaroop/anaconda3/envs/poseidon/lib/python3.9/site-packages/numba/core/serialize.py", line 30, in _numba_unpickle
#     def _numba_unpickle(address, bytedata, hashed):
#   File "/home/swaroop/anaconda3/envs/poseidon/lib/python3.9/site-packages/pymultinest/run.py", line 70, in interrupt_handler
#     sys.exit(1)
# SystemExit: 1
# Acceptance Rate:                        0.978474
# Replacements:                                500
# Total Samples:                               511
# Nested Sampling ln(Z):             -43856.872006
# Acceptance Rate:                        0.951557
# Replacements:                                550
# Total Samples:                               578
# Nested Sampling ln(Z):             -35314.587129
# Acceptance Rate:                        0.921659
# Replacements:                                600
# Total Samples:                               651
# Nested Sampling ln(Z):             -28011.751390
# Acceptance Rate:                        0.864362
# Replacements:                                650
# Total Samples:                               752
# Nested Sampling ln(Z):             -20518.185405
# Acceptance Rate:                        0.830368
# Replacements:                                700
# Total Samples:                               843
# Nested Sampling ln(Z):             -15484.385078
# Acceptance Rate:                        0.795334
# Replacements:                                750
# Total Samples:                               943
# Nested Sampling ln(Z):             -10781.589156
# Acceptance Rate:                        0.788177
# Replacements:                                800
# Total Samples:                              1015
# Nested Sampling ln(Z):              -8080.959215
# Acceptance Rate:                        0.784133
# Replacements:                                850
# Total Samples:                              1084
# Nested Sampling ln(Z):              -6033.115554
# Acceptance Rate:                        0.765306
# Replacements:                                900
# Total Samples:                              1176
# Nested Sampling ln(Z):              -4447.295749
# Acceptance Rate:                        0.758786
# Replacements:                                950
# Total Samples:                              1252
# Nested Sampling ln(Z):              -2659.057408
# Acceptance Rate:                        0.746826
# Replacements:                               1000
# Total Samples:                              1339
# Nested Sampling ln(Z):              -1802.699055
# Acceptance Rate:                        0.739437
# Replacements:                               1050
# Total Samples:                              1420
# Nested Sampling ln(Z):              -1035.046355
# Acceptance Rate:                        0.731383
# Replacements:                               1100
# Total Samples:                              1504
# Nested Sampling ln(Z):               -478.590244
# Acceptance Rate:                        0.724181
# Replacements:                               1150
# Total Samples:                              1588
# Nested Sampling ln(Z):                101.115593
# Acceptance Rate:                        0.724638
# Replacements:                               1200
# Total Samples:                              1656
# Nested Sampling ln(Z):                471.551820
# Acceptance Rate:                        0.718804
# Replacements:                               1250
# Total Samples:                              1739
# Nested Sampling ln(Z):                762.815578
# Acceptance Rate:                        0.719823
# Replacements:                               1300
# Total Samples:                              1806
# Nested Sampling ln(Z):               1049.004813
# Acceptance Rate:                        0.718085
# Replacements:                               1350
# Total Samples:                              1880
# Nested Sampling ln(Z):               1272.139058
# Acceptance Rate:                        0.720165
# Replacements:                               1400
# Total Samples:                              1944
# Nested Sampling ln(Z):               1427.633869
# Acceptance Rate:                        0.717112
# Replacements:                               1450
# Total Samples:                              2022
# Nested Sampling ln(Z):               1545.514652
# Acceptance Rate:                        0.707547
# Replacements:                               1500
# Total Samples:                              2120
# Nested Sampling ln(Z):               1644.426236
# Acceptance Rate:                        0.706794
# Replacements:                               1550
# Total Samples:                              2193
# Nested Sampling ln(Z):               1723.429144
# Acceptance Rate:                        0.705156
# Replacements:                               1600
# Total Samples:                              2269
# Nested Sampling ln(Z):               1789.549630
# Acceptance Rate:                        0.701232
# Replacements:                               1650
# Total Samples:                              2353
# Nested Sampling ln(Z):               1828.750928
# Acceptance Rate:                        0.695866
# Replacements:                               1700
# Total Samples:                              2443
# Nested Sampling ln(Z):               1863.609183
# Acceptance Rate:                        0.694169
# Replacements:                               1750
# Total Samples:                              2521
# Nested Sampling ln(Z):               1894.865869
# Acceptance Rate:                        0.687023
# Replacements:                               1800
# Total Samples:                              2620
# Nested Sampling ln(Z):               1920.169638
# Acceptance Rate:                        0.685947
# Replacements:                               1850
# Total Samples:                              2697
# Nested Sampling ln(Z):               1942.388313
# Acceptance Rate:                        0.685179
# Replacements:                               1900
# Total Samples:                              2773
# Nested Sampling ln(Z):               1959.996927
# Acceptance Rate:                        0.684451
# Replacements:                               1950
# Total Samples:                              2849
# Nested Sampling ln(Z):               1973.214550
# Acceptance Rate:                        0.681896
# Replacements:                               2000
# Total Samples:                              2933
# Nested Sampling ln(Z):               1984.724573
# Acceptance Rate:                        0.681969
# Replacements:                               2050
# Total Samples:                              3006
# Nested Sampling ln(Z):               1995.178045
# Acceptance Rate:                        0.678733
# Replacements:                               2100
# Total Samples:                              3094
# Nested Sampling ln(Z):               2003.025052
# Acceptance Rate:                        0.675039
# Replacements:                               2150
# Total Samples:                              3185
# Nested Sampling ln(Z):               2010.950119
# Acceptance Rate:                        0.674226
# Replacements:                               2200
# Total Samples:                              3263
# Nested Sampling ln(Z):               2017.306251
# Acceptance Rate:                        0.671842
# Replacements:                               2250
# Total Samples:                              3349
# Nested Sampling ln(Z):               2022.927926
# Acceptance Rate:                        0.666667
# Replacements:                               2300
# Total Samples:                              3450
# Nested Sampling ln(Z):               2027.915592
# Acceptance Rate:                        0.667045
# Replacements:                               2350
# Total Samples:                              3523
# Nested Sampling ln(Z):               2031.053290
# Acceptance Rate:                        0.665004
# Replacements:                               2400
# Total Samples:                              3609
# Nested Sampling ln(Z):               2034.196380
# Acceptance Rate:                        0.663058
# Replacements:                               2450
# Total Samples:                              3695
# Nested Sampling ln(Z):               2037.487642
# Acceptance Rate:                        0.663834
# Replacements:                               2500
# Total Samples:                              3766
# Nested Sampling ln(Z):               2040.460153
# Acceptance Rate:                        0.662338
# Replacements:                               2550
# Total Samples:                              3850
# Nested Sampling ln(Z):               2042.606594
# Acceptance Rate:                        0.660234
# Replacements:                               2600
# Total Samples:                              3938
# Nested Sampling ln(Z):               2044.142153
# Acceptance Rate:                        0.659861
# Replacements:                               2650
# Total Samples:                              4016
# Nested Sampling ln(Z):               2045.512681
# Acceptance Rate:                        0.657094
# Replacements:                               2700
# Total Samples:                              4109
# Nested Sampling ln(Z):               2046.741436
# Acceptance Rate:                        0.656325
# Replacements:                               2750
# Total Samples:                              4190
# Nested Sampling ln(Z):               2047.792077
# Acceptance Rate:                        0.652225
# Replacements:                               2800
# Total Samples:                              4293
# Nested Sampling ln(Z):               2048.711786
# Acceptance Rate:                        0.648612
# Replacements:                               2850
# Total Samples:                              4394
# Nested Sampling ln(Z):               2049.444384
# Acceptance Rate:                        0.646600
# Replacements:                               2900
# Total Samples:                              4485
# Nested Sampling ln(Z):               2050.041600
# Acceptance Rate:                        0.643543
# Replacements:                               2950
# Total Samples:                              4584
# Nested Sampling ln(Z):               2050.579769
# Acceptance Rate:                        0.641300
# Replacements:                               3000
# Total Samples:                              4678
# Nested Sampling ln(Z):               2051.025450
# Acceptance Rate:                        0.640622
# Replacements:                               3050
# Total Samples:                              4761
# Nested Sampling ln(Z):               2051.396434
# Acceptance Rate:                        0.638517
# Replacements:                               3100
# Total Samples:                              4855
# Nested Sampling ln(Z):               2051.719012
# Acceptance Rate:                        0.638039
# Replacements:                               3150
# Total Samples:                              4937
# Nested Sampling ln(Z):               2052.006713
# Acceptance Rate:                        0.637069
# Replacements:                               3200
# Total Samples:                              5023
# Nested Sampling ln(Z):               2052.240805
# Acceptance Rate:                        0.634146
# Replacements:                               3250
# Total Samples:                              5125
# Nested Sampling ln(Z):               2052.442680
# Acceptance Rate:                        0.634006
# Replacements:                               3300
# Total Samples:                              5205
# Nested Sampling ln(Z):               2052.630696
# Acceptance Rate:                        0.632553
# Replacements:                               3350
# Total Samples:                              5296
# Nested Sampling ln(Z):               2052.813866
# Acceptance Rate:                        0.632323
# Replacements:                               3400
# Total Samples:                              5377
# Nested Sampling ln(Z):               2052.993164
# Acceptance Rate:                        0.631059
# Replacements:                               3450
# Total Samples:                              5467
# Nested Sampling ln(Z):               2053.167119
# Acceptance Rate:                        0.632111
# Replacements:                               3500
# Total Samples:                              5537
# Nested Sampling ln(Z):               2053.323909
# Acceptance Rate:                        0.631785
# Replacements:                               3550
# Total Samples:                              5619
# Nested Sampling ln(Z):               2053.470557
# Acceptance Rate:                        0.631025
# Replacements:                               3600
# Total Samples:                              5705
# Nested Sampling ln(Z):               2053.604313
# Acceptance Rate:                        0.629636
# Replacements:                               3650
# Total Samples:                              5797
# Nested Sampling ln(Z):               2053.729343
# Acceptance Rate:                        0.627544
# Replacements:                               3700
# Total Samples:                              5896
# Nested Sampling ln(Z):               2053.847144
# Acceptance Rate:                        0.627720
# Replacements:                               3750
# Total Samples:                              5974
# Nested Sampling ln(Z):               2053.953133
# Acceptance Rate:                        0.627995
# Replacements:                               3800
# Total Samples:                              6051
# Nested Sampling ln(Z):               2054.049092
# Acceptance Rate:                        0.627240
# Replacements:                               3850
# Total Samples:                              6138
# Nested Sampling ln(Z):               2054.137788
# Acceptance Rate:                        0.625602
# Replacements:                               3900
# Total Samples:                              6234
# Nested Sampling ln(Z):               2054.219081
# Acceptance Rate:                        0.624111
# Replacements:                               3950
# Total Samples:                              6329
# Nested Sampling ln(Z):               2054.292945
# Acceptance Rate:                        0.622568
# Replacements:                               4000
# Total Samples:                              6425
# Nested Sampling ln(Z):               2054.360631
# Acceptance Rate:                        0.621356
# Replacements:                               4050
# Total Samples:                              6518
# Nested Sampling ln(Z):               2054.421785
# Acceptance Rate:                        0.620554
# Replacements:                               4100
# Total Samples:                              6607
# Nested Sampling ln(Z):               2054.476735
# Acceptance Rate:                        0.618941
# Replacements:                               4150
# Total Samples:                              6705
# Nested Sampling ln(Z):               2054.526425
# Acceptance Rate:                        0.618466
# Replacements:                               4200
# Total Samples:                              6791
# Nested Sampling ln(Z):               2054.571063
# Acceptance Rate:                        0.618452
# Replacements:                               4250
# Total Samples:                              6872
# Nested Sampling ln(Z):               2054.610992
# Acceptance Rate:                        0.617095
# Replacements:                               4274
# Total Samples:                              6926
# Nested Sampling ln(Z):               2054.628720
# POSEIDON retrieval finished in 0.39 hours
#  ln(ev)=   2054.9422863078753      +/-  0.13429804659947006
#  Total Likelihood Evaluations:         6926
#  Sampling finished. Exiting MultiNest
# Now generating 1000 sampled spectra and P-T profiles from the posterior distribution...
# This process will take approximately 3.0 minutes
# All done! Output files can be found in ./POSEIDON_output/TOI-1266 c/retrievals/results/

# %%
model_name_3 = 'retr3'

bulk_species_3 = ['CO2']
param_species_3 = ['H2O']  

# Create the model object
model_3 = define_model(model_name_3, bulk_species_3, param_species_3,
                       PT_profile = 'isotherm', cloud_model = 'cloud-free')

opac_3 = read_opacities(model_3, wl, opacity_treatment, T_fine, log_P_fine)


#***** Set priors for new retrieval *****#

# Initialise prior type dictionary
prior_types_3 = {}

# Specify whether priors are linear, Gaussian, etc.
prior_types_3['T'] = 'uniform'
prior_types_3['R_p_ref'] = 'uniform'
prior_types_3['log_X'] = 'uniform'    # 'log_X' sets the same prior for all mixing ratios

# Initialise prior range dictionary
prior_ranges_3 = {}

# Specify prior ranges for each free parameter
prior_ranges_3['T'] = [100, 1000]
prior_ranges_3['R_p_ref'] = [0.85*R_p, 1.15*R_p]
prior_ranges_3['log_X'] = [-12, -1]   # 'log_X' sets the same prior for all mixing ratios

# Create prior object for retrieval
priors_3 = set_priors(planet, star, model_3, data_new, prior_types_3, prior_ranges_3)
# Out:
# Reading in cross sections in opacity sampling mode...
# CO2-CO2 done
# CO2 done
# H2O done
# Opacity pre-interpolation complete.

# %%
run_retrieval(planet, star, model_3, opac_3, data_new, priors_3, wl, P, P_ref, R = R,
              spectrum_type = 'transmission', sampling_algorithm = 'MultiNest',
              N_live = 400, verbose = True)
# Out:
# POSEIDON now running 'retr3'
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  400
#  dimensionality =    3
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.997783
# Replacements:                                450
# Total Samples:                               451
# Nested Sampling ln(Z):             -54846.298855
# Acceptance Rate:                        0.976562
# Replacements:                                500
# Total Samples:                               512
# Nested Sampling ln(Z):             -43334.135200
# Acceptance Rate:                        0.945017
# Replacements:                                550
# Total Samples:                               582
# Nested Sampling ln(Z):             -33523.872136
# Acceptance Rate:                        0.914634
# Replacements:                                600
# Total Samples:                               656
# Nested Sampling ln(Z):             -27439.328284
# Acceptance Rate:                        0.887978
# Replacements:                                650
# Total Samples:                               732
# Nested Sampling ln(Z):             -22080.844521
# Acceptance Rate:                        0.832342
# Replacements:                                700
# Total Samples:                               841
# Nested Sampling ln(Z):             -15662.697843
# Acceptance Rate:                        0.820569
# Replacements:                                750
# Total Samples:                               914
# Nested Sampling ln(Z):             -11789.224102
# Acceptance Rate:                        0.812183
# Replacements:                                800
# Total Samples:                               985
# Nested Sampling ln(Z):              -8512.803309
# Acceptance Rate:                        0.813397
# Replacements:                                850
# Total Samples:                              1045
# Nested Sampling ln(Z):              -6211.870039
# Acceptance Rate:                        0.807899
# Replacements:                                900
# Total Samples:                              1114
# Nested Sampling ln(Z):              -4253.100473
# Acceptance Rate:                        0.791667
# Replacements:                                950
# Total Samples:                              1200
# Nested Sampling ln(Z):              -2964.212890
# Acceptance Rate:                        0.779423
# Replacements:                               1000
# Total Samples:                              1283
# Nested Sampling ln(Z):              -2147.792974
# Acceptance Rate:                        0.762527
# Replacements:                               1050
# Total Samples:                              1377
# Nested Sampling ln(Z):              -1142.193802
# Acceptance Rate:                        0.754976
# Replacements:                               1100
# Total Samples:                              1457
# Nested Sampling ln(Z):               -302.276755
# Acceptance Rate:                        0.747724
# Replacements:                               1150
# Total Samples:                              1538
# Nested Sampling ln(Z):                168.721090
# Acceptance Rate:                        0.750000
# Replacements:                               1200
# Total Samples:                              1600
# Nested Sampling ln(Z):                554.698104
# Acceptance Rate:                        0.744491
# Replacements:                               1250
# Total Samples:                              1679
# Nested Sampling ln(Z):                855.756964
# Acceptance Rate:                        0.741163
# Replacements:                               1300
# Total Samples:                              1754
# Nested Sampling ln(Z):               1161.858228
# Acceptance Rate:                        0.739726
# Replacements:                               1350
# Total Samples:                              1825
# Nested Sampling ln(Z):               1379.281774
# Acceptance Rate:                        0.737619
# Replacements:                               1400
# Total Samples:                              1898
# Nested Sampling ln(Z):               1497.799137
# Acceptance Rate:                        0.730479
# Replacements:                               1450
# Total Samples:                              1985
# Nested Sampling ln(Z):               1615.939949
# Acceptance Rate:                        0.720115
# Replacements:                               1500
# Total Samples:                              2083
# Nested Sampling ln(Z):               1694.359714
# Acceptance Rate:                        0.706150
# Replacements:                               1550
# Total Samples:                              2195
# Nested Sampling ln(Z):               1762.604023
# Acceptance Rate:                        0.692941
# Replacements:                               1600
# Total Samples:                              2309
# Nested Sampling ln(Z):               1801.717697
# Acceptance Rate:                        0.686642
# Replacements:                               1650
# Total Samples:                              2403
# Nested Sampling ln(Z):               1842.623850
# Acceptance Rate:                        0.684380
# Replacements:                               1700
# Total Samples:                              2484
# Nested Sampling ln(Z):               1876.143523
# Acceptance Rate:                        0.681464
# Replacements:                               1750
# Total Samples:                              2568
# Nested Sampling ln(Z):               1898.935606
# Acceptance Rate:                        0.675929
# Replacements:                               1800
# Total Samples:                              2663
# Nested Sampling ln(Z):               1917.350762
# Acceptance Rate:                        0.672972
# Replacements:                               1850
# Total Samples:                              2749
# Nested Sampling ln(Z):               1933.558635
# Acceptance Rate:                        0.670904
# Replacements:                               1900
# Total Samples:                              2832
# Nested Sampling ln(Z):               1948.852740
# Acceptance Rate:                        0.664848
# Replacements:                               1950
# Total Samples:                              2933
# Nested Sampling ln(Z):               1962.863377
# Acceptance Rate:                        0.663350
# Replacements:                               2000
# Total Samples:                              3015
# Nested Sampling ln(Z):               1974.954827
# Acceptance Rate:                        0.663216
# Replacements:                               2050
# Total Samples:                              3091
# Nested Sampling ln(Z):               1984.245629
# Acceptance Rate:                        0.656250
# Replacements:                               2100
# Total Samples:                              3200
# Nested Sampling ln(Z):               1994.505446
# Acceptance Rate:                        0.654291
# Replacements:                               2150
# Total Samples:                              3286
# Nested Sampling ln(Z):               2003.258281
# Acceptance Rate:                        0.649926
# Replacements:                               2200
# Total Samples:                              3385
# Nested Sampling ln(Z):               2010.121885
# Acceptance Rate:                        0.648041
# Replacements:                               2250
# Total Samples:                              3472
# Nested Sampling ln(Z):               2015.974682
# Acceptance Rate:                        0.646976
# Replacements:                               2300
# Total Samples:                              3555
# Nested Sampling ln(Z):               2021.166398
# Acceptance Rate:                        0.646315
# Replacements:                               2350
# Total Samples:                              3636
# Nested Sampling ln(Z):               2025.465613
# Acceptance Rate:                        0.645856
# Replacements:                               2400
# Total Samples:                              3716
# Nested Sampling ln(Z):               2028.160952
# Acceptance Rate:                        0.646950
# Replacements:                               2450
# Total Samples:                              3787
# Nested Sampling ln(Z):               2031.262832
# Acceptance Rate:                        0.647501
# Replacements:                               2500
# Total Samples:                              3861
# Nested Sampling ln(Z):               2033.968639
# Acceptance Rate:                        0.648855
# Replacements:                               2550
# Total Samples:                              3930
# Nested Sampling ln(Z):               2036.374275
# Acceptance Rate:                        0.650976
# Replacements:                               2600
# Total Samples:                              3994
# Nested Sampling ln(Z):               2038.740457
# Acceptance Rate:                        0.650307
# Replacements:                               2650
# Total Samples:                              4075
# Nested Sampling ln(Z):               2040.867054
# Acceptance Rate:                        0.649195
# Replacements:                               2700
# Total Samples:                              4159
# Nested Sampling ln(Z):               2042.588468
# Acceptance Rate:                        0.650118
# Replacements:                               2750
# Total Samples:                              4230
# Nested Sampling ln(Z):               2044.023968
# Acceptance Rate:                        0.648749
# Replacements:                               2800
# Total Samples:                              4316
# Nested Sampling ln(Z):               2045.229687
# Acceptance Rate:                        0.650536
# Replacements:                               2850
# Total Samples:                              4381
# Nested Sampling ln(Z):               2046.263245
# Acceptance Rate:                        0.649933
# Replacements:                               2900
# Total Samples:                              4462
# Nested Sampling ln(Z):               2047.163128
# Acceptance Rate:                        0.651790
# Replacements:                               2950
# Total Samples:                              4526
# Nested Sampling ln(Z):               2047.932492
# Acceptance Rate:                        0.652600
# Replacements:                               3000
# Total Samples:                              4597
# Nested Sampling ln(Z):               2048.667748
# Acceptance Rate:                        0.653245
# Replacements:                               3050
# Total Samples:                              4669
# Nested Sampling ln(Z):               2049.269867
# Acceptance Rate:                        0.651124
# Replacements:                               3100
# Total Samples:                              4761
# Nested Sampling ln(Z):               2049.824719
# Acceptance Rate:                        0.649887
# Replacements:                               3150
# Total Samples:                              4847
# Nested Sampling ln(Z):               2050.303806
# Acceptance Rate:                        0.649482
# Replacements:                               3200
# Total Samples:                              4927
# Nested Sampling ln(Z):               2050.707926
# Acceptance Rate:                        0.650651
# Replacements:                               3250
# Total Samples:                              4995
# Nested Sampling ln(Z):               2051.056405
# Acceptance Rate:                        0.650888
# Replacements:                               3300
# Total Samples:                              5070
# Nested Sampling ln(Z):               2051.346597
# Acceptance Rate:                        0.651118
# Replacements:                               3350
# Total Samples:                              5145
# Nested Sampling ln(Z):               2051.586343
# Acceptance Rate:                        0.652716
# Replacements:                               3400
# Total Samples:                              5209
# Nested Sampling ln(Z):               2051.783681
# Acceptance Rate:                        0.652174
# Replacements:                               3450
# Total Samples:                              5290
# Nested Sampling ln(Z):               2051.949045
# Acceptance Rate:                        0.653595
# Replacements:                               3500
# Total Samples:                              5355
# Nested Sampling ln(Z):               2052.093803
# Acceptance Rate:                        0.654982
# Replacements:                               3550
# Total Samples:                              5420
# Nested Sampling ln(Z):               2052.224462
# Acceptance Rate:                        0.655977
# Replacements:                               3600
# Total Samples:                              5488
# Nested Sampling ln(Z):               2052.350082
# Acceptance Rate:                        0.657421
# Replacements:                               3650
# Total Samples:                              5552
# Nested Sampling ln(Z):               2052.473689
# Acceptance Rate:                        0.657310
# Replacements:                               3700
# Total Samples:                              5629
# Nested Sampling ln(Z):               2052.593017
# Acceptance Rate:                        0.658704
# Replacements:                               3750
# Total Samples:                              5693
# Nested Sampling ln(Z):               2052.706810
# Acceptance Rate:                        0.659264
# Replacements:                               3800
# Total Samples:                              5764
# Nested Sampling ln(Z):               2052.815458
# Acceptance Rate:                        0.659698
# Replacements:                               3850
# Total Samples:                              5836
# Nested Sampling ln(Z):               2052.918725
# Acceptance Rate:                        0.658339
# Replacements:                               3900
# Total Samples:                              5924
# Nested Sampling ln(Z):               2053.019246
# Acceptance Rate:                        0.659102
# Replacements:                               3950
# Total Samples:                              5993
# Nested Sampling ln(Z):               2053.115625
# Acceptance Rate:                        0.658003
# Replacements:                               4000
# Total Samples:                              6079
# Nested Sampling ln(Z):               2053.207742
# Acceptance Rate:                        0.658109
# Replacements:                               4050
# Total Samples:                              6154
# Nested Sampling ln(Z):               2053.299131
# Acceptance Rate:                        0.656630
# Replacements:                               4100
# Total Samples:                              6244
# Nested Sampling ln(Z):               2053.384948
# Acceptance Rate:                        0.656023
# Replacements:                               4150
# Total Samples:                              6326
# Nested Sampling ln(Z):               2053.464036
# Acceptance Rate:                        0.656147
# Replacements:                               4200
# Total Samples:                              6401
# Nested Sampling ln(Z):               2053.537614
# Acceptance Rate:                        0.657284
# Replacements:                               4250
# Total Samples:                              6466
# Nested Sampling ln(Z):               2053.604161
# Acceptance Rate:                        0.657895
# Replacements:                               4300
# Total Samples:                              6536
# Nested Sampling ln(Z):               2053.665208
# Acceptance Rate:                        0.658393
# Replacements:                               4350
# Total Samples:                              6607
# Nested Sampling ln(Z):               2053.722224
# Acceptance Rate:                        0.658288
# Replacements:                               4400
# Total Samples:                              6684
# Nested Sampling ln(Z):               2053.774192
# Acceptance Rate:                        0.658771
# Replacements:                               4450
# Total Samples:                              6755
# Nested Sampling ln(Z):               2053.822244
# Acceptance Rate:                        0.658569
# Replacements:                               4500
# Total Samples:                              6833
# Nested Sampling ln(Z):               2053.867255
# Acceptance Rate:                        0.658847
# Replacements:                               4550
# Total Samples:                              6906
# Nested Sampling ln(Z):               2053.908655
# Acceptance Rate:                        0.659120
# Replacements:                               4600
# Total Samples:                              6979
# Nested Sampling ln(Z):               2053.947089
# Acceptance Rate:                        0.658827
# Replacements:                               4650
# Total Samples:                              7058
# Nested Sampling ln(Z):               2053.983362
# Acceptance Rate:                        0.658909
# Replacements:                               4700
# Total Samples:                              7133
# Nested Sampling ln(Z):               2054.017282
# Acceptance Rate:                        0.658482
# Replacements:                               4747
# Total Samples:                              7209
# Nested Sampling ln(Z):               2054.046615
# POSEIDON retrieval finished in 0.4 hours
#  ln(ev)=   2054.3234164644605      +/-  0.14057772006181815
#  Total Likelihood Evaluations:         7209
#  Sampling finished. Exiting MultiNest
# Now generating 1000 sampled spectra and P-T profiles from the posterior distribution...
# This process will take approximately 3.0 minutes
# All done! Output files can be found in ./POSEIDON_output/TOI-1266 c/retrievals/results/

# %%
wl, spec_low2, spec_low1, spec_median, spec_high1, spec_high2 = read_retrieved_spectrum(planet_name, model_name_2)

spectra_median = plot_collection(spec_median, wl, collection = spectra_median)
spectra_low1 = plot_collection(spec_low1, wl, collection = spectra_low1)
spectra_low2 = plot_collection(spec_low2, wl, collection = spectra_low2)
spectra_high1 = plot_collection(spec_high1, wl, collection = spectra_high1)
spectra_high2 = plot_collection(spec_high2, wl, collection = spectra_high2)

fig_spec = plot_spectra_retrieved(spectra_median, spectra_low2, spectra_low1,
                                  spectra_high1, spectra_high2, planet_name,
                                  data_new, R_to_bin = 100,
                                  data_labels = ['NIRSpec Prism'],
                                  spectra_labels=['Ref(CO2+H2O+CH4)', 'CO2+CH4'],
                                  figure_shape = 'wide', wl_axis = 'linear',
                                  plt_label = 'Simulated JWST Retrieval')

fig_corner = generate_cornerplot(planet, model_2)
# Out:
# Generating corner plot ...

# %%
wl, spec_low2, spec_low1, spec_median, spec_high1, spec_high2 = read_retrieved_spectrum(planet_name, model_name_3)

spectra_median = plot_collection(spec_median, wl, collection = spectra_median)
spectra_low1 = plot_collection(spec_low1, wl, collection = spectra_low1)
spectra_low2 = plot_collection(spec_low2, wl, collection = spectra_low2)
spectra_high1 = plot_collection(spec_high1, wl, collection = spectra_high1)
spectra_high2 = plot_collection(spec_high2, wl, collection = spectra_high2)

fig_spec = plot_spectra_retrieved(spectra_median, spectra_low2, spectra_low1,
                                  spectra_high1, spectra_high2, planet_name,
                                  data_new, R_to_bin = 100,
                                  data_labels = ['NIRSpec Prism'],
                                  spectra_labels=['Ref(CO2+H2O+CH4)', 'CO2+CH4', 'CO2+H2O'],
                                  figure_shape = 'wide', wl_axis = 'linear',
                                  plt_label = 'Simulated JWST Retrieval')

fig_corner = generate_cornerplot(planet, model_3)
# Out:
# Generating corner plot ...

# %%
from POSEIDON.retrieval import Bayesian_model_comparison

model_ref = model
model_h2otest = model_2 
model_ch4test = model_3

Bayesian_model_comparison(planet_name, model_ref, model_h2otest)
# Out:
# Bayesian evidences:
#
# Model retr1: ln Z = 2055.70 +/- 0.13
# Model retr2: ln Z = 2054.94 +/- 0.13
#
# Bayes factor:
#
# B = 2.14e+00
# ln B = 0.76
#
# 'Equivalent' detection significance:
#
# 1.9 σ

# %%
Bayesian_model_comparison(planet_name, model_ref, model_ch4test)
# Out:
# Bayesian evidences:
#
# Model retr1: ln Z = 2055.70 +/- 0.13
# Model retr3: ln Z = 2054.32 +/- 0.14
#
# Bayes factor:
#
# B = 3.97e+00
# ln B = 1.38
#
# 'Equivalent' detection significance:
#
# 2.2 σ
